# %% [markdown]
# # Add some additional layers of information to the hierarchy
#
# Requires DDOT for ontology parsing https://github.com/michaelkyu/ddot/blob/master/examples/Tutorial.ipynb

# %%
# load required packages

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import pandas as pd
import random

import ndex2
import getpass

from IPython.display import display

# latex rendering of text in graphs
import matplotlib as mpl
mpl.rc('text', usetex = False)
mpl.rc('font', family = 'serif')

from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']

sns.set(font_scale=1.4)

sns.set_style('white')

sns.set_style("ticks", {"xtick.major.size": 15, "ytick.major.size": 15})
plt.rcParams['svg.fonttype'] = 'none'

import sys

# % matplotlib inline

# %%
# need ddot to parse the ontology
import ddot
from ddot import Ontology

# %%
# ddot only compatible with nx 1.11....
nx.__version__
# Out:
# '1.11'

# %% [markdown]
# # Load interactome (needs to be the same one used in previous analysis)

# %%
interactome_uuid='4de852d9-9908-11e9-bcaf-0ac135e8bacf'
ndex_server='public.ndexbio.org'
ndex_user=None
ndex_password=None
G_PC = ndex2.create_nice_cx_from_server(
            ndex_server, 
            username=ndex_user, 
            password=ndex_password, 
            uuid=interactome_uuid
        ).to_networkx()

# relabel nodes.... this is a nx 1.11 thing...
G_PC_data = pd.DataFrame.from_dict(dict(G_PC.nodes(data=True)), orient='index')
G_PC = nx.relabel_nodes(G_PC,dict(zip(G_PC_data.index.tolist(),G_PC_data['name'].tolist())))
print(G_PC.nodes()[0:5])
nodes = G_PC.nodes()

# print out interactome num nodes and edges for diagnostic purposes
print('number of nodes:')
print(len(G_PC.nodes()))
print('\nnumber of edges:')
print(len(G_PC.edges()))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-202-070dc35d6826> in <module>
#       7             username=ndex_user,
#       8             password=ndex_password,
# ----> 9             uuid=interactome_uuid
#      10         ).to_networkx()
#      11
#
# ~/anaconda3/lib/python3.7/site-packages/ndex2/__init__.py in create_nice_cx_from_server(server, username, password, uuid)
#     584         else:
#     585             if not username or not password:
# --> 586                 raise Exception('Network is not available.  Username and/or password not supplied')
#     587             else:
#     588                 raise Exception('Network not available')
#
# Exception: Network is not available.  Username and/or password not supplied

# %% [markdown]
# # Load ASD rare-common hierarchy from ndex

# %%
ASD_uuid='0e4f9da9-9d5d-11eb-9e72-0ac135e8bacf'
ndex_server='public.ndexbio.org'
ndex_user='sbrosenthal@health.ucsd.edu'
ndex_password=getpass.getpass('NDEx password: ')
G_ASD = ndex2.create_nice_cx_from_server(
            ndex_server, 
            username=ndex_user, 
            password=ndex_password, 
            uuid=ASD_uuid
        ).to_networkx()
nodes = G_ASD.nodes()

# print out interactome num nodes and edges for diagnostic purposes
print('number of nodes:')
print(len(G_ASD.nodes()))
print('\nnumber of edges:')
print(len(G_ASD.edges()))
# Out:
# NDEx password: ········
# number of nodes:
# 73
#
# number of edges:
# 74

# %%
G_ASD.nodes(data=True)[0:2]
# Out:
# [(6869,
#   {'CD_MemberList': 'NSG2 PSD2 SLC17A6 STXBP5L',
#    'CD_AnnotatedMembers_Size': '0',
#    'CD_AnnotatedMembers_Pvalue': '0.0',
#    'CD_AnnotatedMembers_Overlap': '0.0',
#    'HiDeF_persistence': '5',
#    'CD_MemberList_LogSize': '2.0',
#    'CD_Labeled': 'false',
#    'CD_MemberList_Size': '4',
#    'name': 'C435'}),
#  (6868,
#   {'CD_MemberList': 'EN1 GSX2 IRX3 NKX6-2',
#    'CD_AnnotatedMembers_Size': '0',
#    'CD_AnnotatedMembers_Pvalue': '0.0',
#    'CD_AnnotatedMembers_Overlap': '0.0',
#    'HiDeF_persistence': '5',
#    'CD_MemberList_LogSize': '2.0',
#    'CD_Labeled': 'false',
#    'CD_MemberList_Size': '4',
#    'name': 'C434'})]

# %%
# add node attributes to dataframe for easier access
ASD_clust_df = pd.DataFrame.from_dict(dict(G_ASD.nodes(data=True)), orient='index')
# relabel nodes in G_ASD
G_ASD=nx.relabel_nodes(G_ASD,dict(ASD_clust_df['name']))
ASD_clust_df.index = ASD_clust_df['name']
# some columns are not the right type
ASD_clust_df['CD_MemberList_Size']=[int(x) for x in ASD_clust_df['CD_MemberList_Size'].tolist()]
ASD_clust_df['HiDeF_persistence']=[int(x) for x in ASD_clust_df['HiDeF_persistence'].tolist()]
ASD_clust_df.head()
# Out:
#                       CD_MemberList CD_AnnotatedMembers_Size  \
# name
# C435      NSG2 PSD2 SLC17A6 STXBP5L                        0
# C434           EN1 GSX2 IRX3 NKX6-2                        0
# C433            CALM3 FSD1 GNAZ SRC                        0
# C432       ABCC8 CDK5R2 KIF1A MKRN3                        0
# C431  LARP1 PPP1R3A RPS6KA6 WDR82P1                        0
#
#      CD_AnnotatedMembers_Pvalue CD_AnnotatedMembers_Overlap  \
# name
# C435                        0.0                         0.0
# C434                        0.0                         0.0
# C433                        0.0                         0.0
# C432                        0.0                         0.0
# C431                        0.0                         0.0
#
#       HiDeF_persistence CD_MemberList_LogSize CD_Labeled  CD_MemberList_Size  \
# name
# C435                  5                   2.0      false                   4
# C434                  5                   2.0      false                   4
# C433                  5                   2.0      false                   4
# C432                 10                   2.0      false                   4
# C431                  6                   2.0      false                   4
#
#       name
# name
# C435  C435
# C434  C434
# C433  C433
# C432  C432
# C431  C431

# %% [markdown]
# # Add some annotation the the systems
#
# - Fraction rare/common/neither seeds
#
#
# ## Do we need to pull down the other network for this?

# %%
ASD_clust_df.head()
# Out:
#                       CD_MemberList CD_AnnotatedMembers_Size  \
# name
# C435      NSG2 PSD2 SLC17A6 STXBP5L                        0
# C434           EN1 GSX2 IRX3 NKX6-2                        0
# C433            CALM3 FSD1 GNAZ SRC                        0
# C432       ABCC8 CDK5R2 KIF1A MKRN3                        0
# C431  LARP1 PPP1R3A RPS6KA6 WDR82P1                        0
#
#      CD_AnnotatedMembers_Pvalue CD_AnnotatedMembers_Overlap  \
# name
# C435                        0.0                         0.0
# C434                        0.0                         0.0
# C433                        0.0                         0.0
# C432                        0.0                         0.0
# C431                        0.0                         0.0
#
#       HiDeF_persistence CD_MemberList_LogSize CD_Labeled  CD_MemberList_Size  \
# name
# C435                  5                   2.0      false                   4
# C434                  5                   2.0      false                   4
# C433                  5                   2.0      false                   4
# C432                 10                   2.0      false                   4
# C431                  6                   2.0      false                   4
#
#       name
# name
# C435  C435
# C434  C434
# C433  C433
# C432  C432
# C431  C431

# %% [markdown]
# # System validation with mammalian phenotype ontology + mouse KO data
#
# Parse the ontology, data from http://www.informatics.jax.org/vocab/mp_ontology

# %%
from scipy.stats import hypergeom
from statsmodels.stats import contingency_tables

# %%
mgi_df = pd.read_csv('../data/MGI/MGI_PhenoGenoMP.rpt',sep='\t',
                    names=['MGI_Allele_Accession_ID','Allele symbol','involves','MP','PMID','MGI_marker_accession_ID'])
gene_name = [a.split('<')[0] for a in mgi_df['Allele symbol'].tolist()]
mgi_df['gene_name']=gene_name
mgi_df.index=mgi_df['gene_name']
mgi_df.head()
# Out:
#            MGI_Allele_Accession_ID Allele symbol               involves  \
# gene_name
# Rb1        Rb1<tm1Tyj>/Rb1<tm1Tyj>   Rb1<tm1Tyj>  involves: 129S2/SvPas
# Rb1        Rb1<tm1Tyj>/Rb1<tm1Tyj>   Rb1<tm1Tyj>  involves: 129S2/SvPas
# Rb1        Rb1<tm1Tyj>/Rb1<tm1Tyj>   Rb1<tm1Tyj>  involves: 129S2/SvPas
# Rb1        Rb1<tm1Tyj>/Rb1<tm1Tyj>   Rb1<tm1Tyj>  involves: 129S2/SvPas
# Rb1        Rb1<tm1Tyj>/Rb1<tm1Tyj>   Rb1<tm1Tyj>  involves: 129S2/SvPas
#
#                    MP      PMID MGI_marker_accession_ID gene_name
# gene_name
# Rb1        MP:0000600  12529408               MGI:97874       Rb1
# Rb1        MP:0001716  16449662               MGI:97874       Rb1
# Rb1        MP:0001698  16449662               MGI:97874       Rb1
# Rb1        MP:0001092  16449662               MGI:97874       Rb1
# Rb1        MP:0000961  16449662               MGI:97874       Rb1

# %%
ddot.parse_obo('../data/MGI/mp.obo',
               '../data/MGI/parsed_mp.txt',
              '../data/MGI/id2name_mp.txt',
              '../data/MGI/id2namespace_mp.txt',
              '../data/MGI/altID_mp.txt')

# %%
MP2desc = pd.read_csv('../data/MGI/id2name_mp.txt',sep='\t',
                      names=['MP','description'],index_col='MP')

MP2desc=MP2desc.loc[MP2desc.index.dropna()] # drop NAN from index
print(len(MP2desc))


MP2desc.head()
# Out:
# 14338
#                                       description
# MP
# MP:0000001                    mammalian phenotype
# MP:0000002                    obsolete Morphology
# MP:0000003     abnormal adipose tissue morphology
# MP:0000011     abnormal adipose tissue morphology
# MP:0000005  increased brown adipose tissue amount

# %%
hierarchy = pd.read_table('../data/MGI/parsed_mp.txt',
                          sep='\t',
                          header=None,
                          names=['Parent', 'Child', 'Relation', 'Namespace'])

hierarchy.head()
# Out:
#        Parent       Child Relation        Namespace
# 0  MP:0005375  MP:0000003     is_a  MPheno.ontology
# 1  MP:0001778  MP:0000005     is_a  MPheno.ontology
# 2  MP:0001781  MP:0000008     is_a  MPheno.ontology
# 3  MP:0005334  MP:0000010     is_a  MPheno.ontology
# 4  MP:0000003  MP:0000013     is_a  MPheno.ontology

# %%
MPO = Ontology.from_table(
    table=hierarchy,
    parent='Parent',
    child='Child',
    add_root_name='MP:00SUPER',
    ignore_orphan_terms=True)
#MPO.clear_node_attr()
#MPO.clear_edge_attr()
MPO
# Out:
# 0 genes, 13205 terms, 0 gene-term relations, 16647 term-term relations
# node_attributes: []
# edge_attributes: ['Relation', 'Namespace']

# %%
print(len(MPO.node_attr))
# Out:
# 13205

# %%
# find terms related to brain
MP_focal_list = []
for t in MPO.node_attr.index.tolist():
    descr_temp = MPO.node_attr.loc[t]['description']
    if descr_temp.find('nervous')>-1:
        print(descr_temp)
        MP_focal_list.append(t)
    elif descr_temp.find('neuron')>-1:
        print(descr_temp)
        MP_focal_list.append(t)
    elif descr_temp.find('synapt')>-1:
        print(descr_temp)
        MP_focal_list.append(t)
        
print(len(MP_focal_list))
# Out:
# abnormal nervous system tract morphology
# hippocampal neuron degeneration
# abnormal motor neuron morphology
# motor neuron degeneration
# decreased motor neuron number
# abnormal motor neuron innervation pattern
# peripheral nervous system degeneration
# abnormal sensory neuron morphology
# decreased sensory neuron number
# abnormal sensory neuron innervation pattern
# abnormal hair guard neuron morphology
# absent hair guard neurons
# abnormal hair-tylotrich neuron morphology
# abnormal hair-down neuron morphology
# absent hair-down neurons
# abnormal sympathetic neuron morphology
# abnormal adrenergic neuron morphology
# abnormal peptidergic neuron morphology
# abnormal parasympathetic neuron morphology
# abnormal cholinergic neuron morphology
# abnormal enteric nervous system morphology
# abnormal enteric neuron morphology
# abnormal enteric cholinergic neuron morphology
# absent enteric neurons
# failure of neuromuscular synapse presynaptic differentiation
# failure of neuromuscular synapse postsynaptic differentiation
# impaired synaptic plasticity
# absence of NMDA-mediated synaptic currents
# reduced NMDA-mediated synaptic currents
# reduced NMDA receptor mediated synaptic activity in barrel cortex
# abnormal CNS synaptic transmission
# abnormal nervous system electrophysiology
# abnormal autonomic nervous system morphology
# abnormal somatic nervous system morphology
# abnormal neuron morphology
# abnormal AMPA-mediated synaptic currents
# abnormal NMDA-mediated synaptic currents
# abnormal excitatory postsynaptic currents
# abnormal inhibitory postsynaptic potential
# abnormal excitatory postsynaptic potential
# abnormal PNS synaptic transmission
# abnormal synaptic depression
# increased synaptic depression
# decreased synaptic depression
# abnormal inhibitory postsynaptic currents
# abnormal neuron specification
# abnormal neuron apoptosis
# increased neuron apoptosis
# decreased neuron apoptosis
# neuron degeneration
# enhanced NMDA-mediated synaptic currents
# loss of hippocampal neurons
# loss of cortex neurons
# loss of basal ganglia neurons
# abnormal dopaminergic neuron morphology
# loss of dopaminergic neurons
# abnormal GABAergic neuron morphology
# loss of GABAergic neurons
# abnormal glutaminergic neuron morphology
# loss of glutamate neurons
# abnormal central nervous system regeneration
# premature neuronal precursor differentiation
# nervous system phenotype
# abnormal nervous system morphology
# abnormal nervous system physiology
# abnormal synaptic transmission
# abnormal nervous system development
# abnormal serotonergic neuron morphology
# abnormal spinal cord interneuron morphology
# abnormal brain interneuron morphology
# abnormal sympathetic nervous system physiology
# neuronal intranuclear inclusions
# abnormal peripheral nervous system regeneration
# abnormal proprioceptive neuron morphology
# abnormal synaptic glutamate release
# decreased synaptic glutamate release
# abnormal inner hair cell synaptic ribbon morphology
# absent active-zone-anchored inner hair cell synaptic ribbon
# abnormal miniature excitatory postsynaptic currents
# abnormal synaptic vesicle morphology
# abnormal synaptic vesicle recycling
# abnormal synaptic vesicle number
# abnormal synaptic vesicle clustering
# abnormal neuron physiology
# abnormal synaptic acetylcholine release
# abnormal nervous system regeneration
# abnormal synaptic plasticity
# abnormal neuronal precursor proliferation
# absent neuronal precursor cells
# abnormal neuronal precursor cell number
# increased neuronal precursor cell number
# decreased neuronal precursor cell number
# increased motor neuron number
# abnormal somatic nervous system physiology
# abnormal synaptic epinephrine release
# abnormal synaptic norepinephrine release
# neuron hypertrophy
# increased sensory neuron number
# abnormal neuronal migration
# abnormal retinal neuronal layer morphology
# abnormal olfactory sensory neuron morphology
# abnormal autonomic nervous system physiology
# abnormal parasympathetic nervous system physiology
# increased susceptibility to neuronal excitotoxicity
# decreased susceptibility to neuronal excitotoxicity
# abnormal medium spiny neuron morphology
# absent proprioceptive neurons
# abnormal synaptic bouton morphology
# nervous
# abnormal neuron number
# increased neuron number
# decreased neuron number
# abnormal sympathetic neuron physiology
# abnormal sympathetic neuron innervation pattern
# abnormal miniature inhibitory postsynaptic currents
# abnormal synaptonemal complex
# abnormal neuron differentiation
# abnormal hippocampus neuron morphology
# abnormal olfactory bulb interneuron morphology
# abnormal neuron proliferation
# abnormal sensory neuron physiology
# abnormal synaptic dopamine release
# increased nervous system tumor incidence
# abnormal thalamus neuron morphology
# abnormal glycinergic neuron morphology
# absence of AMPA-mediated synaptic currents
# enhanced AMPA-mediated synaptic currents
# reduced AMPA-mediated synaptic currents
# abnormal excitatory postsynaptic current amplitude
# biphasic excitatory postsynaptic current amplitude
# increased excitatory postsynaptic current amplitude
# decreased excitatory postsynaptic current amplitude
# prolonged excitatory postsynaptic current rise time
# short excitatory postsynaptic current rise time
# prolonged excitatory postsynaptic current decay time
# short excitatory postsynaptic current decay time
# decreased dopaminergic neuron number
# increased dopaminergic neuron number
# ectopic dopaminergic neuron
# increased susceptibility to dopaminergic neuron neurotoxicity
# decreased susceptibility to dopaminergic neuron neurotoxicity
# abnormal olfactory sensory neuron physiology
# abnormal vomeronasal sensory neuron physiology
# abnormal vomeronasal sensory neuron morphology
# ectopic neuron
# ectopic cortical neuron
# neuronal leptomeningeal ectopia
# abnormal X-Y chromosome synaptonemal complex assembly during male meiosis
# impaired neuron differentiation
# neuronal cytoplasmic inclusions
# abnormal GABAergic neuron physiology
# abnormal olfactory neuron innervation pattern
# abnormal neuronal stem cell morphology
# abnormal neuronal stem cell physiology
# abnormal neuronal stem cell self-renewal
# increased neuronal stem cell self-renewal
# decreased neuronal stem cell self-renewal
# decreased nervous system tumor incidence
# nervous system inclusion bodies
# abnormal dentate gyrus neuron dendrite morphology
# abnormal motor neuron dendrite morphology
# abnormal pyramidal neuron dendrite morphology
# abnormal hippocampal pyramidal neuron dendrite morphology
# decreased olfactory sensory neuron number
# increased neuronal precursor proliferation
# decreased neuronal precursor proliferation
# abnormal postsynaptic density morphology
# abnormal neuron polarity
# abnormal nervous system dopamine level
# decreased nervous system dopamine level
# increased nervous system dopamine level
# impaired central nervous system regeneration
# improved central nervous system regeneration
# abnormal synaptic vesicle exocytosis
# abnormal neuronal precursor cell migration
# 175

# %%
# test for enrichment in root node
OR_p_list,OR_CI_list,log_OR_list = [],[],[]

MP_keep_list = []

# root node is the largest node
root_node = ASD_clust_df['CD_MemberList_Size'].sort_values(ascending=False).head(1).index.tolist()[0]
for MP_focal in MP_focal_list:
    MP_desc_focal = dict(MP2desc['description'])[MP_focal]

    # focus the hierarchy on one branch, and look up all terms within that branch
    if len(MPO.parent_2_child[MP_focal])>0:
        MPO_focal = MPO.focus(MP_focal,verbose=False)
        focal_terms = MPO_focal.terms
    else: # if the term has no children, just look at that term
        focal_terms=[MP_focal]


    # check enrichment in root node
    focal_genes = ASD_clust_df['CD_MemberList'].loc[root_node].split(' ')
    

    mgi_temp = mgi_df[mgi_df['MP'].isin(focal_terms)]
    mgi_genes = list(np.unique(mgi_temp['gene_name']))
    mgi_genes = [g.upper() for g in mgi_genes]
    mgi_genes = list(np.intersect1d(mgi_genes,G_PC.nodes()))
    
    if len(mgi_genes)>10: # only test if there are at least 10 genes
        print('\n'+MP_desc_focal)
        print('number of genes in root node = '+str(len(focal_genes)))
        print('number of genes in focal MPO term = '+str(len(mgi_genes)))

        q00 = len(np.intersect1d(mgi_genes,focal_genes))
        print('number overlapping genes = '+str(q00))
        q01 = len(mgi_genes)-q00

        q10 = len(focal_genes)-q00
        q11 = len(G_PC.nodes())-q00-q01-q10

        table_temp = [[q00,q01],[q10,q11]]
        print(table_temp)

        CT= contingency_tables.Table2x2(table_temp)
        OR_p_temp = CT.log_oddsratio_pvalue()
        OR_CI_temp = CT.log_oddsratio_confint()
        log_OR_temp = CT.log_oddsratio
        print(OR_p_temp)
        print(OR_CI_temp)
        print(log_OR_temp)

        OR_p_list.append(OR_p_temp)
        OR_CI_list.append(OR_CI_temp)
        log_OR_list.append(log_OR_temp)
        
        MP_keep_list.append(MP_focal)

        print(hypergeom.sf(q00,len(G_PC.nodes()),len(focal_genes),len(mgi_genes)))
    
OR_CI_lower, OR_CI_upper = zip(*OR_CI_list)

root_KO_df = pd.DataFrame({'OR_p':OR_p_list,'OR_CI_lower':OR_CI_lower,'OR_CI_upper':OR_CI_upper},
                          index=MP_keep_list)
# Out:
# abnormal nervous system tract morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 188
# number overlapping genes = 15
# [[15, 173], [277, 18355]]
# 2.335897013142731e-10
# (1.2076770372746504, 2.289119755421405)
# 1.7483983963480276
# 4.122755360272459e-08
#
# hippocampal neuron degeneration
# number of genes in root node = 292
# number of genes in focal MPO term = 25
# number overlapping genes = 1
# [[1, 24], [291, 18504]]
# 0.3405477911699869
# (-1.029363442050749, 2.9780936548344226)
# 0.9743651063918368
# 0.05694876545560805
#
# abnormal motor neuron morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 166
# number overlapping genes = 10
# [[10, 156], [282, 18372]]
# 1.6354482238281865e-05
# (0.7793266760396684, 2.079483444464491)
# 1.4294050602520798
# 5.8329668688649927e-05
#
# motor neuron degeneration
# number of genes in root node = 292
# number of genes in focal MPO term = 42
# number overlapping genes = 3
# [[3, 39], [289, 18489]]
# 0.008125918692104933
# (0.41351907905777385, 2.7735913090549937)
# 1.5935551940563837
# 0.003996748903698174
#
# decreased motor neuron number
# number of genes in root node = 292
# number of genes in focal MPO term = 73
# number overlapping genes = 6
# [[6, 67], [286, 18461]]
# 4.5515556678055635e-05
# (0.9111532384624295, 2.5978281951131827)
# 1.754490716787806
# 0.00013680884561816304
#
# abnormal motor neuron innervation pattern
# number of genes in root node = 292
# number of genes in focal MPO term = 44
# number overlapping genes = 4
# [[4, 40], [288, 18488]]
# 0.000426546568415919
# (0.8249489825023488, 2.8937141751461013)
# 1.859331578824225
# 0.0005749613089311303
#
# abnormal sensory neuron morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 465
# number overlapping genes = 20
# [[20, 445], [272, 18083]]
# 3.7220482265705346e-06
# (0.6308584719642751, 1.5583084769891893)
# 1.0945834744767322
# 1.315413298254924e-05
#
# decreased sensory neuron number
# number of genes in root node = 292
# number of genes in focal MPO term = 173
# number overlapping genes = 6
# [[6, 167], [286, 18361]]
# 0.046481217211136794
# (0.013026684152297019, 1.6584892656749726)
# 0.8357579749136348
# 0.01856692266611126
#
# abnormal sensory neuron innervation pattern
# number of genes in root node = 292
# number of genes in focal MPO term = 93
# number overlapping genes = 11
# [[11, 82], [281, 18446]]
# 2.751843610957206e-11
# (1.5351511802507036, 2.815697179741369)
# 2.1754241799960363
# 2.112898275196241e-08
#
# abnormal sympathetic neuron morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 13
# number overlapping genes = 0
# [[0, 13], [292, 18515]]
# 0.5365260701148018
# (-1.9354870751207875, 3.7184593812366846)
# 0.8914861530579485
# 0.18400477242536364
#
# abnormal cholinergic neuron morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 12
# number overlapping genes = 0
# [[0, 12], [292, 18516]]
# 0.5012202081348538
# (-1.8597423250804863, 3.8029080641503543)
# 0.971582869534934
# 0.17113640958677187
#
# abnormal enteric nervous system morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 35
# number overlapping genes = 1
# [[1, 34], [291, 18494]]
# 0.5382413825341976
# (-1.3664288203052954, 2.6174645050051533)
# 0.6255178423499288
# 0.10224364118157965
#
# abnormal enteric neuron morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 27
# number overlapping genes = 0
# [[0, 27], [292, 18501]]
# 0.9109044480571389
# (-2.639900132264657, 2.9595845619187493)
# 0.1598422148270462
# 0.3445898732963503
#
# impaired synaptic plasticity
# number of genes in root node = 292
# number of genes in focal MPO term = 47
# number overlapping genes = 2
# [[2, 45], [290, 18483]]
# 0.15099770965027615
# (-0.379898076680528, 2.4623189516641006)
# 1.0412104374917863
# 0.03631382441942184
#
# abnormal CNS synaptic transmission
# number of genes in root node = 292
# number of genes in focal MPO term = 748
# number overlapping genes = 45
# [[45, 703], [247, 17825]]
# 4.064209561976624e-20
# (1.2037808533999876, 1.8567681598283587)
# 1.5302745066141732
# 1.0445756312808588e-15
#
# abnormal nervous system electrophysiology
# number of genes in root node = 292
# number of genes in focal MPO term = 320
# number overlapping genes = 34
# [[34, 286], [258, 18242]]
# 1.3760453133544927e-28
# (1.7527052894220914, 2.5050767818075004)
# 2.128891035614796
# 8.49558494868396e-20
#
# abnormal autonomic nervous system morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 94
# number overlapping genes = 1
# [[1, 93], [291, 18435]]
# 0.7030465504051107
# (-2.357789317269975, 1.5899564179569667)
# -0.3839164496565042
# 0.42976686242691314
#
# abnormal somatic nervous system morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 980
# number overlapping genes = 47
# [[47, 933], [245, 17595]]
# 2.7690390522369767e-15
# (0.9668742468238668, 1.60483423332348)
# 1.2858542400736734
# 1.2073762371556662e-12
#
# abnormal neuron morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 1472
# number overlapping genes = 69
# [[69, 1403], [223, 17125]]
# 3.193956347682084e-21
# (1.0534308536340715, 1.6042917786961413)
# 1.3288613161651064
# 1.0766968590421017e-17
#
# abnormal AMPA-mediated synaptic currents
# number of genes in root node = 292
# number of genes in focal MPO term = 31
# number overlapping genes = 1
# [[1, 30], [291, 18498]]
# 0.460853435693958
# (-1.244827183183422, 2.7466216797445355)
# 0.7508972482805567
# 0.08313763931828339
#
# abnormal NMDA-mediated synaptic currents
# number of genes in root node = 292
# number of genes in focal MPO term = 22
# number overlapping genes = 1
# [[1, 21], [291, 18507]]
# 0.2797933789357876
# (-0.9013676455559336, 3.117484871521599)
# 1.1080586129828327
# 0.04519231859009093
#
# abnormal excitatory postsynaptic currents
# number of genes in root node = 292
# number of genes in focal MPO term = 127
# number overlapping genes = 7
# [[7, 120], [285, 18408]]
# 0.0007464658653372937
# (0.5554449064697811, 2.097494808969857)
# 1.326469857719819
# 0.000830854165117607
#
# abnormal excitatory postsynaptic potential
# number of genes in root node = 292
# number of genes in focal MPO term = 103
# number overlapping genes = 8
# [[8, 95], [284, 18433]]
# 5.262667577612935e-06
# (0.9674934081085892, 2.4294830467199353)
# 1.6984882274142623
# 3.231079009871059e-05
#
# abnormal PNS synaptic transmission
# number of genes in root node = 292
# number of genes in focal MPO term = 36
# number overlapping genes = 3
# [[3, 33], [289, 18495]]
# 0.0036588373717520327
# (0.5733336152701582, 2.948533871441345)
# 1.7609337433557517
# 0.002261841753386615
#
# abnormal synaptic depression
# number of genes in root node = 292
# number of genes in focal MPO term = 112
# number overlapping genes = 6
# [[6, 106], [286, 18422]]
# 0.0022726866371396456
# (0.4628927161001034, 2.12436617558853)
# 1.2936294458443167
# 0.001823143556997791
#
# increased synaptic depression
# number of genes in root node = 292
# number of genes in focal MPO term = 15
# number overlapping genes = 2
# [[2, 13], [290, 18515]]
# 0.0027104744399343477
# (0.7914420451857083, 3.7778647417454945)
# 2.2846533934656015
# 0.0014647520335292746
#
# decreased synaptic depression
# number of genes in root node = 292
# number of genes in focal MPO term = 14
# number overlapping genes = 1
# [[1, 13], [291, 18515]]
# 0.12655656220219816
# (-0.44918035343213214, 3.625308090861498)
# 1.5880638687146829
# 0.019304507419965578
#
# abnormal inhibitory postsynaptic currents
# number of genes in root node = 292
# number of genes in focal MPO term = 75
# number overlapping genes = 7
# [[7, 68], [285, 18460]]
# 2.2832736952120862e-06
# (1.1105354423791176, 2.6840141009556797)
# 1.8972747716673988
# 2.0916536422439743e-05
#
# abnormal neuron specification
# number of genes in root node = 292
# number of genes in focal MPO term = 14
# number overlapping genes = 2
# [[2, 12], [290, 18516]]
# 0.0020223405010326443
# (0.8633158438301471, 3.8661843760550267)
# 2.364750109942587
# 0.0011853434646458601
#
# abnormal neuron apoptosis
# number of genes in root node = 292
# number of genes in focal MPO term = 217
# number overlapping genes = 7
# [[7, 210], [285, 18318]]
# 0.05003725053609512
# (-0.00012387101471900142, 1.524029671078973)
# 0.761952900032127
# 0.02031224124024791
#
# increased neuron apoptosis
# number of genes in root node = 292
# number of genes in focal MPO term = 154
# number overlapping genes = 5
# [[5, 149], [287, 18379]]
# 0.0952531201296645
# (-0.13372971759737018, 1.6636764739863596)
# 0.7649733781944947
# 0.03320087811696227
# decreased neuron apoptosis
# number of genes in root node = 292
# number of genes in focal MPO term = 70
# number overlapping genes = 2
# [[2, 68], [290, 18460]]
# 0.3836661701815005
# (-0.7837931040950523, 2.038033225015376)
# 0.6271200604601619
# 0.09501981503733828
#
# neuron degeneration
# number of genes in root node = 292
# number of genes in focal MPO term = 387
# number overlapping genes = 16
# [[16, 371], [276, 18157]]
# 7.082414538546484e-05
# (0.5284282899205166, 1.5571661784512119)
# 1.0427972341858642
# 0.0001233673637615258
#
# loss of hippocampal neurons
# number of genes in root node = 292
# number of genes in focal MPO term = 15
# number overlapping genes = 0
# [[0, 15], [292, 18513]]
# 0.6030145036163768
# (-2.0717188299891993, 3.568273396106678)
# 0.7482772830587394
# 0.20914723347278139
#
# loss of cortex neurons
# number of genes in root node = 292
# number of genes in focal MPO term = 17
# number overlapping genes = 1
# [[1, 16], [291, 18512]]
# 0.18126925286086726
# (-0.6433378953410438, 3.403862815385411)
# 1.3802624600221836
# 0.027985015779562125
#
# abnormal dopaminergic neuron morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 43
# number overlapping genes = 3
# [[3, 40], [289, 18488]]
# 0.009135068709843869
# (0.389191029406843, 2.747175567385073)
# 1.568183298395958
# 0.004353738541050144
#
# loss of dopaminergic neurons
# number of genes in root node = 292
# number of genes in focal MPO term = 19
# number overlapping genes = 1
# [[1, 18], [291, 18510]]
# 0.21994454227569638
# (-0.7546267908631523, 3.279369551862924)
# 1.2623713804998857
# 0.03448192672371518
#
# abnormal GABAergic neuron morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 26
# number overlapping genes = 2
# [[2, 24], [290, 18504]]
# 0.02363102106703002
# (0.22380425685364758, 3.1181050054318633)
# 1.6709546311427554
# 0.007380580131955909
#
# premature neuronal precursor differentiation
# number of genes in root node = 292
# number of genes in focal MPO term = 25
# number overlapping genes = 0
# [[0, 25], [292, 18503]]
# 0.8683695309655081
# (-2.56486295827298, 3.038685663043557)
# 0.2369113523852886
# 0.32373972855184396
#
# nervous system phenotype
# number of genes in root node = 292
# number of genes in focal MPO term = 3524
# number overlapping genes = 132
# [[132, 3392], [160, 15136]]
# 7.25250719536444e-28
# (1.0698376623887873, 1.5367311410760338)
# 1.3032844017324106
# 4.447756340771824e-26
#
# abnormal nervous system morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 2799
# number overlapping genes = 111
# [[111, 2688], [181, 15840]]
# 8.548397463701224e-26
# (1.0449765170119085, 1.524571750531861)
# 1.2847741337718848
# 3.4384117797326163e-23
#
# abnormal nervous system physiology
# number of genes in root node = 292
# number of genes in focal MPO term = 2009
# number overlapping genes = 92
# [[92, 1917], [200, 16611]]
# 4.2431041820528264e-27
# (1.1313838784690902, 1.6341658674237827)
# 1.3827748729464364
# 3.872616263580695e-23
#
# abnormal synaptic transmission
# number of genes in root node = 292
# number of genes in focal MPO term = 940
# number overlapping genes = 51
# [[51, 889], [241, 17639]]
# 1.0312937161448965e-19
# (1.125281302702863, 1.7443169019596239)
# 1.4347991023312434
# 8.886284517565308e-16
#
# abnormal nervous system development
# number of genes in root node = 292
# number of genes in focal MPO term = 1279
# number overlapping genes = 58
# [[58, 1221], [234, 17307]]
# 4.567624308608452e-17
# (0.9632767793334284, 1.549848708672597)
# 1.2565627440030127
# 2.651335619385286e-14
#
# abnormal spinal cord interneuron morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 33
# number overlapping genes = 4
# [[4, 29], [288, 18499]]
# 4.8044797685129616e-05
# (1.1296664541280206, 3.2333535589696982)
# 2.1815100065488595
# 0.00014440936708218013
#
# abnormal brain interneuron morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 38
# number overlapping genes = 5
# [[5, 33], [287, 18495]]
# 2.4501166904840978e-06
# (1.3309210670586211, 3.2264866118904854)
# 2.278703839474553
# 2.4093025205109295e-05
#
# abnormal sympathetic nervous system physiology
# number of genes in root node = 292
# number of genes in focal MPO term = 27
# number overlapping genes = 0
# [[0, 27], [292, 18501]]
# 0.9109044480571389
# (-2.639900132264657, 2.9595845619187493)
# 0.1598422148270462
# 0.3445898732963503
#
# abnormal proprioceptive neuron morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 17
# number overlapping genes = 0
# [[0, 17], [292, 18511]]
# 0.6644143858331306
# (-2.191642901128336, 3.4376551052788193)
# 0.6230061020752418
# 0.23351757591027478
#
# abnormal synaptic glutamate release
# number of genes in root node = 292
# number of genes in focal MPO term = 14
# number overlapping genes = 0
# [[0, 14], [292, 18514]]
# 0.5704374208211285
# (-2.005913462941659, 3.6405618013090013)
# 0.8173241691836712
# 0.1966740235737086
#
# abnormal miniature excitatory postsynaptic currents
# number of genes in root node = 292
# number of genes in focal MPO term = 116
# number overlapping genes = 8
# [[8, 108], [284, 18420]]
# 2.3623764179492608e-05
# (0.8418703432690384, 2.2971864291383772)
# 1.5695283862037077
# 8.236626074733365e-05
#
# abnormal synaptic vesicle morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 47
# number overlapping genes = 5
# [[5, 42], [287, 18486]]
# 1.9350536574848924e-05
# (1.1025242832054718, 2.9715858092261933)
# 2.0370550462158326
# 8.336177980361424e-05
#
# abnormal synaptic vesicle recycling
# number of genes in root node = 292
# number of genes in focal MPO term = 19
# number overlapping genes = 2
# [[2, 17], [290, 18511]]
# 0.0071742151579365825
# (0.5464279532989562, 3.485918731666833)
# 2.0161733424828947
# 0.002979576375815365
#
# abnormal synaptic vesicle number
# number of genes in root node = 292
# number of genes in focal MPO term = 40
# number overlapping genes = 5
# [[5, 35], [287, 18493]]
# 4.076852225643973e-06
# (1.27548811042745, 3.1640222821124317)
# 2.219755196269941
# 3.263779244741189e-05
#
# abnormal neuron physiology
# number of genes in root node = 292
# number of genes in focal MPO term = 598
# number overlapping genes = 37
# [[37, 561], [255, 17967]]
# 2.174030198645884e-17
# (1.1813324253392754, 1.8911185404520745)
# 1.536225482895675
# 1.5203770620769945e-13
#
# abnormal nervous system regeneration
# number of genes in root node = 292
# number of genes in focal MPO term = 19
# number overlapping genes = 2
# [[2, 17], [290, 18511]]
# 0.0071742151579365825
# (0.5464279532989562, 3.485918731666833)
# 2.0161733424828947
# 0.002979576375815365
#
# abnormal synaptic plasticity
# number of genes in root node = 292
# number of genes in focal MPO term = 69
# number overlapping genes = 2
# [[2, 67], [290, 18461]]
# 0.3725924075633762
# (-0.7692226140646701, 2.053201245982729)
# 0.6419893159590293
# 0.09195043338645985
#
# abnormal neuronal precursor proliferation
# number of genes in root node = 292
# number of genes in focal MPO term = 80
# number overlapping genes = 4
# [[4, 76], [288, 18452]]
# 0.018583450477685903
# (0.2033740511081381, 2.2276831196425118)
# 1.215528585375325
# 0.008104847148622037
#
# abnormal neuronal precursor cell number
# number of genes in root node = 292
# number of genes in focal MPO term = 64
# number overlapping genes = 4
# [[4, 60], [288, 18468]]
# 0.0051918118323693654
# (0.43399294432343627, 2.4715752604540127)
# 1.4527841023887245
# 0.0031389709584433555
#
# increased neuronal precursor cell number
# number of genes in root node = 292
# number of genes in focal MPO term = 19
# number overlapping genes = 1
# [[1, 18], [291, 18510]]
# 0.21994454227569638
# (-0.7546267908631523, 3.279369551862924)
# 1.2623713804998857
# 0.03448192672371518
#
# decreased neuronal precursor cell number
# number of genes in root node = 292
# number of genes in focal MPO term = 43
# number overlapping genes = 1
# [[1, 42], [291, 18486]]
# 0.6830966737813391
# (-1.5727613119538704, 2.4003134766935927)
# 0.4137760823698611
# 0.14343262071612706
#
# increased motor neuron number
# number of genes in root node = 292
# number of genes in focal MPO term = 11
# number overlapping genes = 1
# [[1, 10], [291, 18518]]
# 0.07812410747727289
# (-0.20829620754804745, 3.9094765092329546)
# 1.8505901508424536
# 0.012029927463292856
#
# abnormal somatic nervous system physiology
# number of genes in root node = 292
# number of genes in focal MPO term = 72
# number overlapping genes = 5
# [[5, 67], [287, 18461]]
# 0.0007902939838220029
# (0.6525892782854944, 2.4847682318226707)
# 1.5686787550540826
# 0.0008776924445438458
# increased sensory neuron number
# number of genes in root node = 292
# number of genes in focal MPO term = 52
# number overlapping genes = 7
# [[7, 45], [285, 18483]]
# 1.8188310568892242e-08
# (1.5064848946321163, 3.11624540276593)
# 2.311365148699023
# 1.2700627284175902e-06
#
# abnormal neuronal migration
# number of genes in root node = 292
# number of genes in focal MPO term = 127
# number overlapping genes = 7
# [[7, 120], [285, 18408]]
# 0.0007464658653372937
# (0.5554449064697811, 2.097494808969857)
# 1.326469857719819
# 0.000830854165117607
#
# abnormal retinal neuronal layer morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 350
# number overlapping genes = 11
# [[11, 339], [281, 18189]]
# 0.017454251392781988
# (0.13020010517321612, 1.354025476474817)
# 0.7421127908240166
# 0.008807473221156468
#
# abnormal olfactory sensory neuron morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 24
# number overlapping genes = 2
# [[2, 22], [290, 18506]]
# 0.01765201029461214
# (0.3059049633566786, 3.2102432107034913)
# 1.758074087030085
# 0.005877954284737828
#
# abnormal autonomic nervous system physiology
# number of genes in root node = 292
# number of genes in focal MPO term = 43
# number overlapping genes = 1
# [[1, 42], [291, 18486]]
# 0.6830966737813391
# (-1.5727613119538704, 2.4003134766935927)
# 0.4137760823698611
# 0.14343262071612706
#
# abnormal parasympathetic nervous system physiology
# number of genes in root node = 292
# number of genes in focal MPO term = 12
# number overlapping genes = 1
# [[1, 11], [291, 18517]]
# 0.09338245397860352
# (-0.2951619696292096, 3.805613905765116)
# 1.7552259680679532
# 0.014289294987732197
#
# increased susceptibility to neuronal excitotoxicity
# number of genes in root node = 292
# number of genes in focal MPO term = 30
# number overlapping genes = 1
# [[1, 29], [291, 18499]]
# 0.4410848583645801
# (-1.2119774961998546, 2.7816832129866995)
# 0.7848528583934224
# 0.07855166747489066
#
# decreased susceptibility to neuronal excitotoxicity
# number of genes in root node = 292
# number of genes in focal MPO term = 32
# number overlapping genes = 0
# [[0, 32], [292, 18496]]
# 0.9942235371127878
# (-2.8060965255624306, 2.7854422972507336)
# -0.010327114155848527
# 0.3939548970095386
#
# abnormal synaptic bouton morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 20
# number overlapping genes = 1
# [[1, 19], [291, 18509]]
# 0.23971122705428372
# (-0.8059616977389124, 3.2224619635764804)
# 1.208250132918784
# 0.037928197353114534
#
# abnormal neuron number
# number of genes in root node = 292
# number of genes in focal MPO term = 461
# number overlapping genes = 26
# [[26, 435], [266, 18093]]
# 3.072541468680818e-11
# (0.9887312074399965, 1.8163379931003936)
# 1.402534600270195
# 3.6980289610671108e-09
#
# increased neuron number
# number of genes in root node = 292
# number of genes in focal MPO term = 85
# number overlapping genes = 9
# [[9, 76], [283, 18452]]
# 1.0888408430210007e-08
# (1.343146789037268, 2.7447979791314565)
# 2.043972384084362
# 7.774316631466154e-07
#
# decreased neuron number
# number of genes in root node = 292
# number of genes in focal MPO term = 385
# number overlapping genes = 21
# [[21, 364], [271, 18164]]
# 6.099369315238841e-09
# (0.8965226553258853, 1.8083706275237619)
# 1.3524466414248235
# 1.6775652849851536e-07
#
# abnormal miniature inhibitory postsynaptic currents
# number of genes in root node = 292
# number of genes in focal MPO term = 48
# number overlapping genes = 4
# [[4, 44], [288, 18484]]
# 0.0007913459318781332
# (0.733651238152577, 2.7939587999591033)
# 1.76380501905584
# 0.0008619335865148737
#
# abnormal synaptonemal complex
# number of genes in root node = 292
# number of genes in focal MPO term = 24
# number overlapping genes = 0
# [[0, 24], [292, 18504]]
# 0.8459838428086519
# (-2.5251292523373507, 3.0807040338075558)
# 0.2777873907351025
# 0.31306809004780056
#
# abnormal neuron differentiation
# number of genes in root node = 292
# number of genes in focal MPO term = 309
# number overlapping genes = 19
# [[19, 290], [273, 18238]]
# 1.5665971508704499e-09
# (0.997067782821248, 1.9556299561678945)
# 1.4763488694945712
# 8.426395655596928e-08
#
# abnormal hippocampus neuron morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 117
# number overlapping genes = 9
# [[9, 108], [283, 18420]]
# 1.5672156037936002e-06
# (1.0007804831729024, 2.380897041583218)
# 1.69083876237806
# 1.4329542895840912e-05
#
# abnormal neuron proliferation
# number of genes in root node = 292
# number of genes in focal MPO term = 108
# number overlapping genes = 6
# [[6, 102], [286, 18426]]
# 0.0016888721277607596
# (0.5007211968406827, 2.1639044727449344)
# 1.3323128347928086
# 0.0014785396152285437
#
# abnormal sensory neuron physiology
# number of genes in root node = 292
# number of genes in focal MPO term = 61
# number overlapping genes = 4
# [[4, 57], [288, 18471]]
# 0.003862350093390952
# (0.4837962512733036, 2.5246834021841247)
# 1.504239826728714
# 0.002543084126560324
#
# abnormal synaptic dopamine release
# number of genes in root node = 292
# number of genes in focal MPO term = 12
# number overlapping genes = 0
# [[0, 12], [292, 18516]]
# 0.5012202081348538
# (-1.8597423250804863, 3.8029080641503543)
# 0.971582869534934
# 0.17113640958677187
#
# increased nervous system tumor incidence
# number of genes in root node = 292
# number of genes in focal MPO term = 55
# number overlapping genes = 2
# [[2, 53], [290, 18475]]
# 0.2248918547881984
# (-0.5394196291823741, 2.293715808869787)
# 0.8771480898437063
# 0.05373938663804336
#
# reduced AMPA-mediated synaptic currents
# number of genes in root node = 292
# number of genes in focal MPO term = 16
# number overlapping genes = 0
# [[0, 16], [292, 18512]]
# 0.6343194783497113
# (-2.1334719801344324, 3.500841468865331)
# 0.6836847443654492
# 0.2214274253135972
#
# abnormal excitatory postsynaptic current amplitude
# number of genes in root node = 292
# number of genes in focal MPO term = 31
# number overlapping genes = 2
# [[2, 29], [290, 18499]]
# 0.04340834697927194
# (0.043858446469202894, 2.919026319819479)
# 1.481442383144341
# 0.012055075756875042
#
# increased excitatory postsynaptic current amplitude
# number of genes in root node = 292
# number of genes in focal MPO term = 11
# number overlapping genes = 1
# [[1, 10], [291, 18518]]
# 0.07812410747727289
# (-0.20829620754804745, 3.9094765092329546)
# 1.8505901508424536
# 0.012029927463292856
#
# decreased excitatory postsynaptic current amplitude
# number of genes in root node = 292
# number of genes in focal MPO term = 21
# number overlapping genes = 1
# [[1, 20], [291, 18508]]
# 0.2596792228087118
# (-0.8547980153282224, 3.168603633931037)
# 1.1569028093014073
# 0.04149989216729133
#
# decreased dopaminergic neuron number
# number of genes in root node = 292
# number of genes in focal MPO term = 24
# number overlapping genes = 3
# [[3, 21], [289, 18507]]
# 0.0003570346787914264
# (0.9982845107759224, 3.428850450644083)
# 2.2135674807100028
# 0.00047214941286228743
#
# increased susceptibility to dopaminergic neuron neurotoxicity
# number of genes in root node = 292
# number of genes in focal MPO term = 13
# number overlapping genes = 1
# [[1, 12], [291, 18516]]
# 0.10956727546390566
# (-0.37511833495000557, 3.711439505333342)
# 1.6681605851916683
# 0.016716055428094623
#
# decreased susceptibility to dopaminergic neuron neurotoxicity
# number of genes in root node = 292
# number of genes in focal MPO term = 12
# number overlapping genes = 0
# [[0, 12], [292, 18516]]
# 0.5012202081348538
# (-1.8597423250804863, 3.8029080641503543)
# 0.971582869534934
# 0.17113640958677187
#
# ectopic neuron
# number of genes in root node = 292
# number of genes in focal MPO term = 64
# number overlapping genes = 6
# [[6, 58], [286, 18470]]
# 1.1515646801391596e-05
# (1.050631914261966, 2.7478235278481726)
# 1.8992277210550692
# 5.873726098908741e-05
#
# impaired neuron differentiation
# number of genes in root node = 292
# number of genes in focal MPO term = 12
# number overlapping genes = 0
# [[0, 12], [292, 18516]]
# 0.5012202081348538
# (-1.8597423250804863, 3.8029080641503543)
# 0.971582869534934
# 0.17113640958677187
#
# nervous system inclusion bodies
# number of genes in root node = 292
# number of genes in focal MPO term = 57
# number overlapping genes = 2
# [[2, 55], [290, 18473]]
# 0.24483496465154964
# (-0.5756385692642241, 2.2556356850754087)
# 0.8399985579055924
# 0.05861957081705705
#
# abnormal pyramidal neuron dendrite morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 14
# number overlapping genes = 0
# [[0, 14], [292, 18514]]
# 0.5704374208211285
# (-2.005913462941659, 3.6405618013090013)
# 0.8173241691836712
# 0.1966740235737086
# decreased neuronal precursor proliferation
# number of genes in root node = 292
# number of genes in focal MPO term = 11
# number overlapping genes = 0
# [[0, 11], [292, 18517]]
# 0.46446474434102136
# (-1.7778115670155863, 3.895108071838024)
# 1.0586482524112188
# 0.1580658166929844
#
# abnormal postsynaptic density morphology
# number of genes in root node = 292
# number of genes in focal MPO term = 16
# number overlapping genes = 0
# [[0, 16], [292, 18512]]
# 0.6343194783497113
# (-2.1334719801344324, 3.500841468865331)
# 0.6836847443654492
# 0.2214274253135972

# %%
root_KO_df['MP_description']=root_KO_df.index.map(dict(MP2desc['description']))

root_KO_df=root_KO_df.sort_values('OR_p')
root_KO_df.head(10)
# Out:
#                     OR_p  OR_CI_lower  OR_CI_upper  \
# MP:0002272  1.376045e-28     1.752705     2.505077
# MP:0003631  7.252507e-28     1.069838     1.536731
# MP:0003633  4.243104e-27     1.131384     1.634166
# MP:0003632  8.548397e-26     1.044977     1.524572
# MP:0002882  3.193956e-21     1.053431     1.604292
# MP:0002206  4.064210e-20     1.203781     1.856768
# MP:0003635  1.031294e-19     1.125281     1.744317
# MP:0004811  2.174030e-17     1.181332     1.891119
# MP:0003861  4.567624e-17     0.963277     1.549849
# MP:0002752  2.769039e-15     0.966874     1.604834
#
#                                         MP_description
# MP:0002272   abnormal nervous system electrophysiology
# MP:0003631                    nervous system phenotype
# MP:0003633          abnormal nervous system physiology
# MP:0003632          abnormal nervous system morphology
# MP:0002882                  abnormal neuron morphology
# MP:0002206          abnormal CNS synaptic transmission
# MP:0003635              abnormal synaptic transmission
# MP:0004811                  abnormal neuron physiology
# MP:0003861         abnormal nervous system development
# MP:0002752  abnormal somatic nervous system morphology

# %% [markdown]
# # Test for enrichment in all systems

# %%
MP_focal_top = root_KO_df.head(10).index.tolist()

MP_full_results_df=pd.DataFrame(index=ASD_clust_df.index.tolist())

for MP_focal in MP_focal_top:
    MP_desc_focal = dict(MP2desc['description'])[MP_focal]
    print(MP_desc_focal)

    # focus the hierarchy on one branch, and look up all terms within that branch
    if len(MPO.parent_2_child[MP_focal])>0:
        MPO_focal = MPO.focus(MP_focal)
        focal_terms = MPO_focal.terms
    else: # if the term has no children, just look at that term
        focal_terms=MP_focal


    hyper_p_list = []
    num_genes_list = []
    genes_id_list = []

    OR_p_list,OR_CI_list,log_OR_list=[],[],[]
    for focal_cluster in ASD_clust_df.index.tolist():
        #print(focal_cluster)
        mFocal_genes = ASD_clust_df['CD_MemberList'].loc[focal_cluster].split(' ')


        from scipy.stats import hypergeom
        M=len(list(G_PC.nodes())) # only keep genes in PCnet
        # Look up all entries matching focal_terms, and mFocal_genes
        mgi_temp = mgi_df[mgi_df['MP'].isin(focal_terms)]
        new_index=[g.upper() for g in mgi_temp.index.tolist()]
        mgi_temp.index=new_index

        N=len(np.intersect1d(list(np.unique(mgi_temp.index.tolist())),list(G_PC.nodes()))) # only keep genes in PCnet

        if len(np.intersect1d(mFocal_genes,mgi_temp.index.tolist()))>0:
            mgi_genes = mgi_temp.index.tolist()
            mgi_genes = list(np.intersect1d(mgi_genes,list(G_PC.nodes())))
            x = len(np.intersect1d(mFocal_genes,mgi_genes))
            #print(x)
            n=len(mFocal_genes)

            #mgi_temp['MP_description']=mgi_temp['MP'].map(dict(MP2desc['description']))



            #print(hypergeom.sf(x,M,n,N))
            hyper_p_list.append(hypergeom.sf(x,M,n,N))
            num_genes_list.append(x)
            genes_id_list.append(' '.join(list(np.intersect1d(mFocal_genes,mgi_genes))))

            q00 = len(np.intersect1d(mgi_genes,mFocal_genes))
            q01 = len(mgi_genes)-q00

            q10 = len(mFocal_genes)-q00
            q11 = len(list(G_PC.nodes()))-q00-q01-q10

            table_temp = [[q00,q01],[q10,q11]]

            CT= contingency_tables.Table2x2(table_temp)
            OR_p_temp = CT.log_oddsratio_pvalue()
            OR_CI_temp = CT.log_oddsratio_confint()
            log_OR_temp = CT.log_oddsratio
            #print(OR_p_temp)


            OR_p_list.append(OR_p_temp)
            OR_CI_list.append(OR_CI_temp)
            log_OR_list.append(log_OR_temp)


        else:
            hyper_p_list.append(1)
            num_genes_list.append(0)
            genes_id_list.append('')

            OR_p_list.append(1)
            OR_CI_list.append(0)
            log_OR_list.append(0)



    MP_focal_df = pd.DataFrame({MP_desc_focal+':-log(hyper_p)':-np.log10(hyper_p_list),
                                MP_desc_focal+':-log(OR_p)':-np.log10(OR_p_list),
                                MP_desc_focal+':log_OR':log_OR_list,
                                MP_desc_focal+':num_genes':num_genes_list,
                                MP_desc_focal+':gene_ids':genes_id_list},index=ASD_clust_df.index.tolist())

    if MP_desc_focal+':-log(hyper_p)' not in MP_full_results_df.columns.tolist():
        MP_full_results_df=MP_full_results_df.join(MP_focal_df)
# Out:
# abnormal nervous system electrophysiology
# Genes and Terms to keep: 34
# nervous system phenotype
# Genes and Terms to keep: 2042
# /Users/brinrosenthal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:83: RuntimeWarning: divide by zero encountered in log10
# abnormal nervous system physiology
# Genes and Terms to keep: 354
# abnormal nervous system morphology
# Genes and Terms to keep: 1687
# abnormal neuron morphology
# Genes and Terms to keep: 262
# abnormal CNS synaptic transmission
# Genes and Terms to keep: 43
# abnormal synaptic transmission
# Genes and Terms to keep: 132
# abnormal neuron physiology
# Genes and Terms to keep: 46
# abnormal nervous system development
# Genes and Terms to keep: 191
# abnormal somatic nervous system morphology
# Genes and Terms to keep: 356

# %%
MP_full_results_df.head()
# Out:
#       abnormal nervous system electrophysiology:-log(hyper_p)  \
# C435                                          -0.000000
# C434                                           4.715884
# C433                                          -0.000000
# C432                                          -0.000000
# C431                                          -0.000000
#
#       abnormal nervous system electrophysiology:-log(OR_p)  \
# C435                                          -0.000000
# C434                                           4.303365
# C433                                          -0.000000
# C432                                          -0.000000
# C431                                          -0.000000
#
#       abnormal nervous system electrophysiology:log_OR  \
# C435                                          0.000000
# C434                                          4.063367
# C433                                          0.000000
# C432                                          0.000000
# C431                                          0.000000
#
#       abnormal nervous system electrophysiology:num_genes  \
# C435                                                  0
# C434                                                  2
# C433                                                  0
# C432                                                  0
# C431                                                  0
#
#      abnormal nervous system electrophysiology:gene_ids  \
# C435
# C434                                         EN1 NKX6-2
# C433
# C432
# C431
#
#       nervous system phenotype:-log(hyper_p)  \
# C435                                2.910936
# C434                                2.910936
# C433                                0.791776
# C432                                1.646664
# C431                                0.791776
#
#       nervous system phenotype:-log(OR_p)  nervous system phenotype:log_OR  \
# C435                             1.581589                         2.567393
# C434                             1.581589                         2.567393
# C433                             0.125505                         0.369470
# C432                             0.847538                         1.468432
# C431                             0.125505                         0.369470
#
#       nervous system phenotype:num_genes nervous system phenotype:gene_ids  \
# C435                                   3              PSD2 SLC17A6 STXBP5L
# C434                                   3                   EN1 GSX2 NKX6-2
# C433                                   1                              GNAZ
# C432                                   2                      CDK5R2 KIF1A
# C431                                   1                             KIF1A
#
#       ...  abnormal nervous system development:-log(hyper_p)  \
# C435  ...                                          -0.000000
# C434  ...                                           4.672897
# C433  ...                                           1.597754
# C432  ...                                           1.597754
# C431  ...                                          -0.000000
#
#       abnormal nervous system development:-log(OR_p)  \
# C435                                       -0.000000
# C434                                        2.892220
# C433                                        0.725707
# C432                                        0.725707
# C431                                       -0.000000
#
#       abnormal nervous system development:log_OR  \
# C435                                    0.000000
# C434                                    3.719366
# C433                                    1.520461
# C432                                    1.520461
# C431                                    0.000000
#
#       abnormal nervous system development:num_genes  \
# C435                                              0
# C434                                              3
# C433                                              1
# C432                                              1
# C431                                              0
#
#      abnormal nervous system development:gene_ids  \
# C435
# C434                              EN1 GSX2 NKX6-2
# C433                                         GNAZ
# C432                                       CDK5R2
# C431
#
#       abnormal somatic nervous system morphology:-log(hyper_p)  \
# C435                                          -0.000000
# C434                                           5.136098
# C433                                          -0.000000
# C432                                          -0.000000
# C431                                          -0.000000
#
#       abnormal somatic nervous system morphology:-log(OR_p)  \
# C435                                          -0.000000
# C434                                           3.276389
# C433                                          -0.000000
# C432                                          -0.000000
# C431                                          -0.000000
#
#       abnormal somatic nervous system morphology:log_OR  \
# C435                                           0.000000
# C434                                           4.003268
# C433                                           0.000000
# C432                                           0.000000
# C431                                           0.000000
#
#       abnormal somatic nervous system morphology:num_genes  \
# C435                                                  0
# C434                                                  3
# C433                                                  0
# C432                                                  0
# C431                                                  0
#
#      abnormal somatic nervous system morphology:gene_ids
# C435
# C434                                    EN1 GSX2 NKX6-2
# C433
# C432
# C431
#
# [5 rows x 50 columns]

# %%
print(len(MP_full_results_df))
# Out:
# 73

# %% [markdown]
# # Update hierarchy on ndex

# %%
# add new fields as node attributes to hierarchy
MP_full_results_dict = MP_full_results_df.to_dict()

# %%
data
# Out:
# abnormal nervous system electrophysiology:-log(hyper_p)                                               10.1354
# abnormal nervous system electrophysiology:-log(OR_p)                                                  13.3509
# abnormal nervous system electrophysiology:log_OR                                                      3.82752
# abnormal nervous system electrophysiology:num_genes                                                         7
# abnormal nervous system electrophysiology:gene_ids                  KCNC2 KCNK9 KCNN2 KCNQ2 KCNQ3 KCNQ5 KCNT1
# nervous system phenotype:-log(hyper_p)                                                                5.80554
# nervous system phenotype:-log(OR_p)                                                                   4.54729
# nervous system phenotype:log_OR                                                                       2.25925
# nervous system phenotype:num_genes                                                                         11
# nervous system phenotype:gene_ids                           KCNA4 KCNC2 KCNK13 KCNK5 KCNK9 KCNN2 KCNQ2 KCN...
# abnormal nervous system physiology:-log(hyper_p)                                                       8.5914
# abnormal nervous system physiology:-log(OR_p)                                                         7.18838
# abnormal nervous system physiology:log_OR                                                             2.91805
# abnormal nervous system physiology:num_genes                                                               11
# abnormal nervous system physiology:gene_ids                 KCNA4 KCNC2 KCNK13 KCNK5 KCNK9 KCNN2 KCNQ2 KCN...
# abnormal nervous system morphology:-log(hyper_p)                                                      1.64609
# abnormal nervous system morphology:-log(OR_p)                                                         1.11842
# abnormal nervous system morphology:log_OR                                                            0.957282
# abnormal nervous system morphology:num_genes                                                                5
# abnormal nervous system morphology:gene_ids                                    KCNK13 KCNK5 KCNN2 KCNQ3 KCNQ4
# abnormal neuron morphology:-log(hyper_p)                                                             0.444324
# abnormal neuron morphology:-log(OR_p)                                                               0.0886994
# abnormal neuron morphology:log_OR                                                                    -0.24138
# abnormal neuron morphology:num_genes                                                                        1
# abnormal neuron morphology:gene_ids                                                                     KCNQ4
# abnormal CNS synaptic transmission:-log(hyper_p)                                                      2.51241
# abnormal CNS synaptic transmission:-log(OR_p)                                                         2.13741
# abnormal CNS synaptic transmission:log_OR                                                             1.72168
# abnormal CNS synaptic transmission:num_genes                                                                3
# abnormal CNS synaptic transmission:gene_ids                                                 KCNC2 KCNN2 KCNQ2
# abnormal synaptic transmission:-log(hyper_p)                                                          4.10009
# abnormal synaptic transmission:-log(OR_p)                                                             4.19902
# abnormal synaptic transmission:log_OR                                                                 2.16182
# abnormal synaptic transmission:num_genes                                                                    5
# abnormal synaptic transmission:gene_ids                                         KCNC2 KCNK9 KCNN2 KCNQ2 KCNT1
# abnormal neuron physiology:-log(hyper_p)                                                              3.98303
# abnormal neuron physiology:-log(OR_p)                                                                 4.22631
# abnormal neuron physiology:log_OR                                                                     2.32423
# abnormal neuron physiology:num_genes                                                                        4
# abnormal neuron physiology:gene_ids                                                   KCNQ2 KCNQ3 KCNQ4 KCNT1
# abnormal nervous system development:-log(hyper_p)                                                          -0
# abnormal nervous system development:-log(OR_p)                                                             -0
# abnormal nervous system development:log_OR                                                                  0
# abnormal nervous system development:num_genes                                                               0
# abnormal nervous system development:gene_ids
# abnormal somatic nervous system morphology:-log(hyper_p)                                              0.69595
# abnormal somatic nervous system morphology:-log(OR_p)                                               0.0699444
# abnormal somatic nervous system morphology:log_OR                                                    0.193775
# abnormal somatic nervous system morphology:num_genes                                                        1
# abnormal somatic nervous system morphology:gene_ids                                                     KCNQ4
# Name: C371, dtype: object

# %%
G_ASD_cx = ndex2.create_nice_cx_from_networkx(G_ASD)

# %%
# add node attributes to the nice_cx
# for key in MP_full_results_dict.keys():
#     print(key)
#     # set the datatypes
#     if key.find('gene_ids')>-1:
#         data_type='string'
#     else:
#         data_type='double'
#     nx.set_node_attributes(G_ASD_cx,key,MP_full_results_dict[key],type=data_type)
    
for node_id, node in G_ASD_cx.get_nodes():
    data = MP_full_results_df.loc[node['n']]
    for row, value in data.items():
        if row.find('gene_ids')>-1:
            data_type = "string"
            value=str(value)
        else:
            data_type = "double"
            value = str(value) # nice cx can only accept strings as values...
            if value=='inf': # check if inf, set to -1 if so
                value='-1'
            
        #print(value)
        #print(type(value))
        G_ASD_cx.set_node_attribute(node_id, row, value, type=data_type)

# %%
np.log2(900)
# Out:
# 9.813781191217037

# %%
G_ASD_cx.nodeAttributes
# Out:
# {0: [{'po': 0,
#    'n': 'CD_MemberList',
#    'v': 'NSG2 PSD2 SLC17A6 STXBP5L',
#    'd': 'string'},
#   {'po': 0, 'n': 'CD_AnnotatedMembers_Size', 'v': '1', 'd': 'string'},
#   {'po': 0,
#    'n': 'CD_AnnotatedMembers_Pvalue',
#    'v': '0.007995642253764',
#    'd': 'string'},
#   {'po': 0, 'n': 'CD_AnnotatedMembers', 'v': 'SLC17A6', 'd': 'string'},
#   {'po': 0,
#    'n': 'CD_CommunityName',
#    'v': 'Organic anion transporters Homo sapiens R-HSA-428643',
#    'd': 'string'},
#   {'po': 0, 'n': 'CD_AnnotatedMembers_Overlap', 'v': '0.25', 'd': 'string'},
#   {'po': 0, 'n': 'HiDeF_persistence', 'v': '5', 'd': 'string'},
#   {'po': 0, 'n': 'CD_MemberList_LogSize', 'v': '2.0', 'd': 'string'},
#   {'po': 0, 'n': 'CD_Labeled', 'v': 'true', 'd': 'string'},
#   {'po': 0,
#    'n': 'CD_AnnotatedAlgorithm',
#    'v': ['Annotated by Enrichr [Docker: coleslawndex/cdenrichrgenestoterm:0.4.0] {{--maxpval=0.05',
#     ' --genesets=GO_Biological_Process_2018',
#     'GO_Cellular_Component_2018',
#     'GO_Molecular_Function_2018',
#     'KEGG_2019_Human',
#     'Reactome_2016',
#     'WikiPathways_2019_Human',
#     'Human_Phenotype_Ontology',
#     'Jensen_DISEASES}} via CyCommunityDetection Cytoscape App (1.11.0)'],
#    'd': 'list_of_string'},
#   {'po': 0,
#    'n': 'CD_NonAnnotatedMembers',
#    'v': 'NSG2 PSD2 STXBP5L',
#    'd': 'string'},
#   {'po': 0,
#    'n': 'CD_AnnotatedMembers_SourceDB',
#    'v': 'Reactome_2016',
#    'd': 'string'},
#   {'po': 0, 'n': 'CD_MemberList_Size', 'v': '4', 'd': 'string'},
#   {'po': 0, 'n': 'name', 'v': 'C435', 'd': 'string'},
#   {'po': 0,
#    'n': 'abnormal nervous system electrophysiology:-log(hyper_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal nervous system electrophysiology:-log(OR_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal nervous system electrophysiology:log_OR',
#    'v': '0.0',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal nervous system electrophysiology:num_genes',
#    'v': '0',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal nervous system electrophysiology:gene_ids',
#    'v': '',
#    'd': 'string'},
#   {'po': 0,
#    'n': 'nervous system phenotype:-log(hyper_p)',
#    'v': '2.9109360908244195',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'nervous system phenotype:-log(OR_p)',
#    'v': '1.581589363123753',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'nervous system phenotype:log_OR',
#    'v': '2.567393226098061',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'nervous system phenotype:num_genes',
#    'v': '3',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'nervous system phenotype:gene_ids',
#    'v': 'PSD2 SLC17A6 STXBP5L',
#    'd': 'string'},
#   {'po': 0,
#    'n': 'abnormal nervous system physiology:-log(hyper_p)',
#    'v': '2.3496292150226257',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal nervous system physiology:-log(OR_p)',
#    'v': '1.4734895726944748',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal nervous system physiology:log_OR',
#    'v': '2.1252733874370557',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal nervous system physiology:num_genes',
#    'v': '2',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal nervous system physiology:gene_ids',
#    'v': 'SLC17A6 STXBP5L',
#    'd': 'string'},
#   {'po': 0,
#    'n': 'abnormal nervous system morphology:-log(hyper_p)',
#    'v': '3.311259768389211',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal nervous system morphology:-log(OR_p)',
#    'v': '1.8605885931203296',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal nervous system morphology:log_OR',
#    'v': '2.844260405936759',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal nervous system morphology:num_genes',
#    'v': '3',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal nervous system morphology:gene_ids',
#    'v': 'PSD2 SLC17A6 STXBP5L',
#    'd': 'string'},
#   {'po': 0,
#    'n': 'abnormal neuron morphology:-log(hyper_p)',
#    'v': '2.74509491611505',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal neuron morphology:-log(OR_p)',
#    'v': '1.8658920741168623',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal neuron morphology:log_OR',
#    'v': '2.4680995314716183',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal neuron morphology:num_genes',
#    'v': '2',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal neuron morphology:gene_ids',
#    'v': 'PSD2 SLC17A6',
#    'd': 'string'},
#   {'po': 0,
#    'n': 'abnormal CNS synaptic transmission:-log(hyper_p)',
#    'v': '3.61485984263823',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal CNS synaptic transmission:-log(OR_p)',
#    'v': '2.8394604492982887',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal CNS synaptic transmission:log_OR',
#    'v': '3.187282783382514',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal CNS synaptic transmission:num_genes',
#    'v': '2',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal CNS synaptic transmission:gene_ids',
#    'v': 'SLC17A6 STXBP5L',
#    'd': 'string'},
#   {'po': 0,
#    'n': 'abnormal synaptic transmission:-log(hyper_p)',
#    'v': '3.32026337760314',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal synaptic transmission:-log(OR_p)',
#    'v': '2.49215557053884',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal synaptic transmission:log_OR',
#    'v': '2.9475762366415728',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal synaptic transmission:num_genes',
#    'v': '2',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal synaptic transmission:gene_ids',
#    'v': 'SLC17A6 STXBP5L',
#    'd': 'string'},
#   {'po': 0,
#    'n': 'abnormal neuron physiology:-log(hyper_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal neuron physiology:-log(OR_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal neuron physiology:log_OR',
#    'v': '0.0',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal neuron physiology:num_genes',
#    'v': '0',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal neuron physiology:gene_ids',
#    'v': '',
#    'd': 'string'},
#   {'po': 0,
#    'n': 'abnormal nervous system development:-log(hyper_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal nervous system development:-log(OR_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal nervous system development:log_OR',
#    'v': '0.0',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal nervous system development:num_genes',
#    'v': '0',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal nervous system development:gene_ids',
#    'v': '',
#    'd': 'string'},
#   {'po': 0,
#    'n': 'abnormal somatic nervous system morphology:-log(hyper_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal somatic nervous system morphology:-log(OR_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal somatic nervous system morphology:log_OR',
#    'v': '0.0',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal somatic nervous system morphology:num_genes',
#    'v': '0',
#    'd': 'double'},
#   {'po': 0,
#    'n': 'abnormal somatic nervous system morphology:gene_ids',
#    'v': '',
#    'd': 'string'}],
#  1: [{'po': 1,
#    'n': 'CD_MemberList',
#    'v': 'ABCC8 ADARB2 BRINP3 C14orf132 CADM2 CALB1 CALB2 CCK CDK5R2 CHRNA7 CNTN1 CRHBP DCP1B DNM1 DPYSL2 ENC1 ENHO FABP7 FAM171B GABRA2 GABRB2 GABRB3 GABRG1 GABRG2 GAD1 GFAP GNAZ GRIP2 GRM7 INA IRF2BPL JAKMIP1 KIF1A KIF5C LGI1 LRTM2 LSAMP MAPT MKRN3 MOG MPZ NCAM1 NEFM NEGR1 NEUROD1 NSF NSG2 NTM NTRK2 OMG OPCML PCSK1 PIN1P1 PLP1 PRELP PRR36 PSD2 SCN3B SLC17A6 SLC17A7 SLC1A2 SLC6A1 SLITRK1 STMN3 STXBP5L SV2A SV2B SYBU SYN1 SYP TBR1 TIGD6 TMEM63A UNC13B UNC13C UNC13D UNC5C VSNL1 ZNF501',
#    'd': 'string'},
#   {'po': 1, 'n': 'CD_AnnotatedMembers_Size', 'v': '18', 'd': 'string'},
#   {'po': 1,
#    'n': 'CD_AnnotatedMembers_Pvalue',
#    'v': '2.977322934006789E-14',
#    'd': 'string'},
#   {'po': 1,
#    'n': 'CD_AnnotatedMembers',
#    'v': 'GABRA2 UNC13B GABRB3 UNC13C GABRB2 CHRNA7 GAD1 SLC1A2 SLC6A1 SYN1 GABRG2 GABRG1 CRHBP GRM7 MPZ PLP1 SLC17A6 SLC17A7',
#    'd': 'string'},
#   {'po': 1,
#    'n': 'CD_CommunityName',
#    'v': 'chemical synaptic transmission (GO:0007268)',
#    'd': 'string'},
#   {'po': 1, 'n': 'CD_AnnotatedMembers_Overlap', 'v': '0.228', 'd': 'string'},
#   {'po': 1, 'n': 'HiDeF_persistence', 'v': '17', 'd': 'string'},
#   {'po': 1, 'n': 'CD_MemberList_LogSize', 'v': '6.304', 'd': 'string'},
#   {'po': 1, 'n': 'CD_Labeled', 'v': 'true', 'd': 'string'},
#   {'po': 1,
#    'n': 'CD_AnnotatedAlgorithm',
#    'v': ['Annotated by Enrichr [Docker: coleslawndex/cdenrichrgenestoterm:0.4.0] {{--maxpval=0.05',
#     ' --genesets=GO_Biological_Process_2018',
#     'GO_Cellular_Component_2018',
#     'GO_Molecular_Function_2018',
#     'KEGG_2019_Human',
#     'Reactome_2016',
#     'WikiPathways_2019_Human',
#     'Human_Phenotype_Ontology',
#     'Jensen_DISEASES}} via CyCommunityDetection Cytoscape App (1.11.0)'],
#    'd': 'list_of_string'},
#   {'po': 1,
#    'n': 'CD_NonAnnotatedMembers',
#    'v': 'ABCC8 ADARB2 BRINP3 C14orf132 CADM2 CALB1 CALB2 CCK CDK5R2 CNTN1 DCP1B DNM1 DPYSL2 ENC1 ENHO FABP7 FAM171B GFAP GNAZ GRIP2 INA IRF2BPL JAKMIP1 KIF1A KIF5C LGI1 LRTM2 LSAMP MAPT MKRN3 MOG NCAM1 NEFM NEGR1 NEUROD1 NSF NSG2 NTM NTRK2 OMG OPCML PCSK1 PIN1P1 PRELP PRR36 PSD2 SCN3B SLITRK1 STMN3 STXBP5L SV2A SV2B SYBU SYP TBR1 TIGD6 TMEM63A UNC13D UNC5C VSNL1 ZNF501',
#    'd': 'string'},
#   {'po': 1,
#    'n': 'CD_AnnotatedMembers_SourceDB',
#    'v': 'GO_Biological_Process_2018',
#    'd': 'string'},
#   {'po': 1, 'n': 'CD_MemberList_Size', 'v': '79', 'd': 'string'},
#   {'po': 1, 'n': 'name', 'v': 'C367', 'd': 'string'},
#   {'po': 1,
#    'n': 'abnormal nervous system electrophysiology:-log(hyper_p)',
#    'v': '11.378308631243584',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal nervous system electrophysiology:-log(OR_p)',
#    'v': '16.861721948082785',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal nervous system electrophysiology:log_OR',
#    'v': '2.563091268435486',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal nervous system electrophysiology:num_genes',
#    'v': '14',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal nervous system electrophysiology:gene_ids',
#    'v': 'CALB1 CALB2 DNM1 GABRB3 GABRG2 GAD1 GRM7 JAKMIP1 LGI1 MPZ NEFM NEUROD1 PLP1 SLC17A7',
#    'd': 'string'},
#   {'po': 1,
#    'n': 'nervous system phenotype:-log(hyper_p)',
#    'v': '15.78733188414246',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'nervous system phenotype:-log(OR_p)',
#    'v': '15.276982356697582',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'nervous system phenotype:log_OR',
#    'v': '1.8637389605905375',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'nervous system phenotype:num_genes',
#    'v': '47',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'nervous system phenotype:gene_ids',
#    'v': 'CALB1 CALB2 CCK CDK5R2 CHRNA7 CNTN1 DNM1 DPYSL2 ENHO FABP7 GABRA2 GABRB2 GABRB3 GABRG2 GAD1 GFAP GNAZ GRM7 INA JAKMIP1 KIF1A KIF5C LGI1 MAPT MOG MPZ NCAM1 NEFM NEUROD1 NTRK2 PLP1 PSD2 SLC17A6 SLC17A7 SLC1A2 SLC6A1 SLITRK1 STXBP5L SV2A SV2B SYN1 SYP TBR1 UNC13B UNC13C UNC13D UNC5C',
#    'd': 'string'},
#   {'po': 1,
#    'n': 'abnormal nervous system physiology:-log(hyper_p)',
#    'v': '18.113798563079033',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal nervous system physiology:-log(OR_p)',
#    'v': '20.065708191074034',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal nervous system physiology:log_OR',
#    'v': '2.1162998536153035',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal nervous system physiology:num_genes',
#    'v': '39',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal nervous system physiology:gene_ids',
#    'v': 'CALB1 CALB2 CCK CHRNA7 DNM1 FABP7 GABRA2 GABRB2 GABRB3 GABRG2 GAD1 GFAP GRM7 INA JAKMIP1 KIF1A LGI1 MAPT MOG MPZ NEFM NEUROD1 NTRK2 PLP1 SLC17A6 SLC17A7 SLC1A2 SLC6A1 SLITRK1 STXBP5L SV2A SV2B SYN1 SYP TBR1 UNC13B UNC13C UNC13D UNC5C',
#    'd': 'string'},
#   {'po': 1,
#    'n': 'abnormal nervous system morphology:-log(hyper_p)',
#    'v': '10.156577021364644',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal nervous system morphology:-log(OR_p)',
#    'v': '10.705488504223045',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal nervous system morphology:log_OR',
#    'v': '1.525629709711163',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal nervous system morphology:num_genes',
#    'v': '35',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal nervous system morphology:gene_ids',
#    'v': 'CDK5R2 CHRNA7 CNTN1 DNM1 DPYSL2 ENHO FABP7 GABRB2 GABRB3 GABRG2 GAD1 GFAP GNAZ GRM7 JAKMIP1 KIF1A KIF5C LGI1 MAPT MOG MPZ NCAM1 NEFM NEUROD1 NTRK2 PLP1 PSD2 SLC17A6 SLC17A7 SLC1A2 STXBP5L SYN1 TBR1 UNC13B UNC5C',
#    'd': 'string'},
#   {'po': 1,
#    'n': 'abnormal neuron morphology:-log(hyper_p)',
#    'v': '12.3567596698197',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal neuron morphology:-log(OR_p)',
#    'v': '14.743580457324311',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal neuron morphology:log_OR',
#    'v': '1.8834949130420298',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal neuron morphology:num_genes',
#    'v': '28',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal neuron morphology:gene_ids',
#    'v': 'CDK5R2 CHRNA7 CNTN1 DNM1 DPYSL2 ENHO GABRB2 GABRB3 GABRG2 GRM7 KIF1A KIF5C MAPT MOG MPZ NCAM1 NEFM NEUROD1 NTRK2 PLP1 PSD2 SLC17A6 SLC17A7 SLC1A2 SYN1 TBR1 UNC13B UNC5C',
#    'd': 'string'},
#   {'po': 1,
#    'n': 'abnormal CNS synaptic transmission:-log(hyper_p)',
#    'v': '16.754511017178356',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal CNS synaptic transmission:-log(OR_p)',
#    'v': '22.763222649600756',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal CNS synaptic transmission:log_OR',
#    'v': '2.445609093356547',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal CNS synaptic transmission:num_genes',
#    'v': '25',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal CNS synaptic transmission:gene_ids',
#    'v': 'CALB2 CCK CHRNA7 DNM1 FABP7 GABRA2 GABRB2 GABRB3 GABRG2 GAD1 GFAP GRM7 LGI1 MAPT MPZ NTRK2 SLC17A6 SLC17A7 SLC6A1 STXBP5L SV2A SYN1 SYP TBR1 UNC13C',
#    'd': 'string'},
#   {'po': 1,
#    'n': 'abnormal synaptic transmission:-log(hyper_p)',
#    'v': '15.37099001852081',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal synaptic transmission:-log(OR_p)',
#    'v': '20.012689169984874',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal synaptic transmission:log_OR',
#    'v': '2.258443493967071',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal synaptic transmission:num_genes',
#    'v': '26',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal synaptic transmission:gene_ids',
#    'v': 'CALB2 CCK CHRNA7 DNM1 FABP7 GABRA2 GABRB2 GABRB3 GABRG2 GAD1 GFAP GRM7 LGI1 MAPT MPZ NTRK2 SLC17A6 SLC17A7 SLC6A1 SLITRK1 STXBP5L SV2A SYN1 SYP TBR1 UNC13C',
#    'd': 'string'},
#   {'po': 1,
#    'n': 'abnormal neuron physiology:-log(hyper_p)',
#    'v': '10.416252421746707',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal neuron physiology:-log(OR_p)',
#    'v': '14.055958995932446',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal neuron physiology:log_OR',
#    'v': '2.1483048543144987',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal neuron physiology:num_genes',
#    'v': '17',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal neuron physiology:gene_ids',
#    'v': 'CHRNA7 DNM1 GABRG2 GAD1 GFAP GRM7 INA KIF1A MAPT MOG NEFM NEUROD1 NTRK2 PLP1 SYN1 TBR1 UNC5C',
#    'd': 'string'},
#   {'po': 1,
#    'n': 'abnormal nervous system development:-log(hyper_p)',
#    'v': '4.74499182191022',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal nervous system development:-log(OR_p)',
#    'v': '5.0977638782088555',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal nervous system development:log_OR',
#    'v': '1.2569070996852458',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal nervous system development:num_genes',
#    'v': '16',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal nervous system development:gene_ids',
#    'v': 'CDK5R2 CHRNA7 CNTN1 GFAP GNAZ LGI1 MAPT MPZ NCAM1 NEFM NEUROD1 NTRK2 PLP1 SYN1 TBR1 UNC5C',
#    'd': 'string'},
#   {'po': 1,
#    'n': 'abnormal somatic nervous system morphology:-log(hyper_p)',
#    'v': '5.597953913582631',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal somatic nervous system morphology:-log(OR_p)',
#    'v': '6.389370764002741',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal somatic nervous system morphology:log_OR',
#    'v': '1.462643528282963',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal somatic nervous system morphology:num_genes',
#    'v': '15',
#    'd': 'double'},
#   {'po': 1,
#    'n': 'abnormal somatic nervous system morphology:gene_ids',
#    'v': 'CHRNA7 GABRB2 GABRB3 GRM7 KIF5C MAPT MOG MPZ NCAM1 NEFM NEUROD1 NTRK2 PLP1 TBR1 UNC5C',
#    'd': 'string'}],
#  2: [{'po': 2,
#    'n': 'CD_MemberList',
#    'v': 'EN1 GSX2 IRX3 NKX6-2',
#    'd': 'string'},
#   {'po': 2, 'n': 'CD_AnnotatedMembers_Size', 'v': '1', 'd': 'string'},
#   {'po': 2,
#    'n': 'CD_AnnotatedMembers_Pvalue',
#    'v': '0.0047973853522584',
#    'd': 'string'},
#   {'po': 2, 'n': 'CD_AnnotatedMembers', 'v': 'IRX3', 'd': 'string'},
#   {'po': 2,
#    'n': 'CD_CommunityName',
#    'v': 'FTO Obesity Variant Mechanism WP3407',
#    'd': 'string'},
#   {'po': 2, 'n': 'CD_AnnotatedMembers_Overlap', 'v': '0.25', 'd': 'string'},
#   {'po': 2, 'n': 'HiDeF_persistence', 'v': '5', 'd': 'string'},
#   {'po': 2, 'n': 'CD_MemberList_LogSize', 'v': '2.0', 'd': 'string'},
#   {'po': 2, 'n': 'CD_Labeled', 'v': 'true', 'd': 'string'},
#   {'po': 2,
#    'n': 'CD_AnnotatedAlgorithm',
#    'v': ['Annotated by Enrichr [Docker: coleslawndex/cdenrichrgenestoterm:0.4.0] {{--maxpval=0.05',
#     ' --genesets=GO_Biological_Process_2018',
#     'GO_Cellular_Component_2018',
#     'GO_Molecular_Function_2018',
#     'KEGG_2019_Human',
#     'Reactome_2016',
#     'WikiPathways_2019_Human',
#     'Human_Phenotype_Ontology',
#     'Jensen_DISEASES}} via CyCommunityDetection Cytoscape App (1.11.0)'],
#    'd': 'list_of_string'},
#   {'po': 2,
#    'n': 'CD_NonAnnotatedMembers',
#    'v': 'EN1 GSX2 NKX6-2',
#    'd': 'string'},
#   {'po': 2,
#    'n': 'CD_AnnotatedMembers_SourceDB',
#    'v': 'WikiPathways_2019_Human',
#    'd': 'string'},
#   {'po': 2, 'n': 'CD_MemberList_Size', 'v': '4', 'd': 'string'},
#   {'po': 2, 'n': 'name', 'v': 'C434', 'd': 'string'},
#   {'po': 2,
#    'n': 'abnormal nervous system electrophysiology:-log(hyper_p)',
#    'v': '4.715884059185784',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal nervous system electrophysiology:-log(OR_p)',
#    'v': '4.303364796812111',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal nervous system electrophysiology:log_OR',
#    'v': '4.063366514334028',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal nervous system electrophysiology:num_genes',
#    'v': '2',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal nervous system electrophysiology:gene_ids',
#    'v': 'EN1 NKX6-2',
#    'd': 'string'},
#   {'po': 2,
#    'n': 'nervous system phenotype:-log(hyper_p)',
#    'v': '2.9109360908244195',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'nervous system phenotype:-log(OR_p)',
#    'v': '1.581589363123753',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'nervous system phenotype:log_OR',
#    'v': '2.567393226098061',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'nervous system phenotype:num_genes',
#    'v': '3',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'nervous system phenotype:gene_ids',
#    'v': 'EN1 GSX2 NKX6-2',
#    'd': 'string'},
#   {'po': 2,
#    'n': 'abnormal nervous system physiology:-log(hyper_p)',
#    'v': '2.3496292150226257',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal nervous system physiology:-log(OR_p)',
#    'v': '1.4734895726944748',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal nervous system physiology:log_OR',
#    'v': '2.1252733874370557',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal nervous system physiology:num_genes',
#    'v': '2',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal nervous system physiology:gene_ids',
#    'v': 'EN1 NKX6-2',
#    'd': 'string'},
#   {'po': 2,
#    'n': 'abnormal nervous system morphology:-log(hyper_p)',
#    'v': '3.311259768389211',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal nervous system morphology:-log(OR_p)',
#    'v': '1.8605885931203296',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal nervous system morphology:log_OR',
#    'v': '2.844260405936759',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal nervous system morphology:num_genes',
#    'v': '3',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal nervous system morphology:gene_ids',
#    'v': 'EN1 GSX2 NKX6-2',
#    'd': 'string'},
#   {'po': 2,
#    'n': 'abnormal neuron morphology:-log(hyper_p)',
#    'v': '4.428480397188496',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal neuron morphology:-log(OR_p)',
#    'v': '2.6966525918482467',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal neuron morphology:log_OR',
#    'v': '3.567449972255642',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal neuron morphology:num_genes',
#    'v': '3',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal neuron morphology:gene_ids',
#    'v': 'EN1 GSX2 NKX6-2',
#    'd': 'string'},
#   {'po': 2,
#    'n': 'abnormal CNS synaptic transmission:-log(hyper_p)',
#    'v': '2.0470675545538954',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal CNS synaptic transmission:-log(OR_p)',
#    'v': '1.1499010243672818',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal CNS synaptic transmission:log_OR',
#    'v': '2.087275567910905',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal CNS synaptic transmission:num_genes',
#    'v': '1',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal CNS synaptic transmission:gene_ids',
#    'v': 'EN1',
#    'd': 'string'},
#   {'po': 2,
#    'n': 'abnormal synaptic transmission:-log(hyper_p)',
#    'v': '1.8545621189613313',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal synaptic transmission:-log(OR_p)',
#    'v': '0.9598489969487503',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal synaptic transmission:log_OR',
#    'v': '1.8478424815387164',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal synaptic transmission:num_genes',
#    'v': '1',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal synaptic transmission:gene_ids',
#    'v': 'EN1',
#    'd': 'string'},
#   {'po': 2,
#    'n': 'abnormal neuron physiology:-log(hyper_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal neuron physiology:-log(OR_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal neuron physiology:log_OR',
#    'v': '0.0',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal neuron physiology:num_genes',
#    'v': '0',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal neuron physiology:gene_ids',
#    'v': '',
#    'd': 'string'},
#   {'po': 2,
#    'n': 'abnormal nervous system development:-log(hyper_p)',
#    'v': '4.672897040504999',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal nervous system development:-log(OR_p)',
#    'v': '2.8922203444099273',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal nervous system development:log_OR',
#    'v': '3.719366090689549',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal nervous system development:num_genes',
#    'v': '3',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal nervous system development:gene_ids',
#    'v': 'EN1 GSX2 NKX6-2',
#    'd': 'string'},
#   {'po': 2,
#    'n': 'abnormal somatic nervous system morphology:-log(hyper_p)',
#    'v': '5.136097824447622',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal somatic nervous system morphology:-log(OR_p)',
#    'v': '3.2763888883436056',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal somatic nervous system morphology:log_OR',
#    'v': '4.003267987376596',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal somatic nervous system morphology:num_genes',
#    'v': '3',
#    'd': 'double'},
#   {'po': 2,
#    'n': 'abnormal somatic nervous system morphology:gene_ids',
#    'v': 'EN1 GSX2 NKX6-2',
#    'd': 'string'}],
#  3: [{'po': 3,
#    'n': 'CD_MemberList',
#    'v': 'EN1 GSX2 HOXA4 HOXA7 IRX1 IRX3 IRX6 MEIS3P1 MKX MNX1 NKX6-2 PBX1 PBX3 PKNOX1 SUOX',
#    'd': 'string'},
#   {'po': 3, 'n': 'CD_AnnotatedMembers_Size', 'v': '3', 'd': 'string'},
#   {'po': 3,
#    'n': 'CD_AnnotatedMembers_Pvalue',
#    'v': '1.677832487479E-4',
#    'd': 'string'},
#   {'po': 3,
#    'n': 'CD_AnnotatedMembers',
#    'v': 'PKNOX1 PBX1 HOXA4',
#    'd': 'string'},
#   {'po': 3,
#    'n': 'CD_CommunityName',
#    'v': 'Activation of HOX genes during differentiation Homo sapiens R-HSA-5619507',
#    'd': 'string'},
#   {'po': 3, 'n': 'CD_AnnotatedMembers_Overlap', 'v': '0.2', 'd': 'string'},
#   {'po': 3, 'n': 'HiDeF_persistence', 'v': '16', 'd': 'string'},
#   {'po': 3, 'n': 'CD_MemberList_LogSize', 'v': '3.907', 'd': 'string'},
#   {'po': 3, 'n': 'CD_Labeled', 'v': 'true', 'd': 'string'},
#   {'po': 3,
#    'n': 'CD_AnnotatedAlgorithm',
#    'v': ['Annotated by Enrichr [Docker: coleslawndex/cdenrichrgenestoterm:0.4.0] {{--maxpval=0.05',
#     ' --genesets=GO_Biological_Process_2018',
#     'GO_Cellular_Component_2018',
#     'GO_Molecular_Function_2018',
#     'KEGG_2019_Human',
#     'Reactome_2016',
#     'WikiPathways_2019_Human',
#     'Human_Phenotype_Ontology',
#     'Jensen_DISEASES}} via CyCommunityDetection Cytoscape App (1.11.0)'],
#    'd': 'list_of_string'},
#   {'po': 3,
#    'n': 'CD_NonAnnotatedMembers',
#    'v': 'EN1 GSX2 HOXA7 IRX1 IRX3 IRX6 MEIS3P1 MKX MNX1 NKX6-2 PBX3 SUOX',
#    'd': 'string'},
#   {'po': 3,
#    'n': 'CD_AnnotatedMembers_SourceDB',
#    'v': 'Reactome_2016',
#    'd': 'string'},
#   {'po': 3, 'n': 'CD_MemberList_Size', 'v': '15', 'd': 'string'},
#   {'po': 3, 'n': 'name', 'v': 'C372', 'd': 'string'},
#   {'po': 3,
#    'n': 'abnormal nervous system electrophysiology:-log(hyper_p)',
#    'v': '4.0152274276174555',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal nervous system electrophysiology:-log(OR_p)',
#    'v': '4.450680829059861',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal nervous system electrophysiology:log_OR',
#    'v': '2.679681016957047',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal nervous system electrophysiology:num_genes',
#    'v': '3',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal nervous system electrophysiology:gene_ids',
#    'v': 'EN1 MNX1 NKX6-2',
#    'd': 'string'},
#   {'po': 3,
#    'n': 'nervous system phenotype:-log(hyper_p)',
#    'v': '2.562581695333224',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'nervous system phenotype:-log(OR_p)',
#    'v': '2.0047078199398363',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'nervous system phenotype:log_OR',
#    'v': '1.335928460821604',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'nervous system phenotype:num_genes',
#    'v': '7',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'nervous system phenotype:gene_ids',
#    'v': 'EN1 GSX2 IRX1 IRX6 MNX1 NKX6-2 PBX3',
#    'd': 'string'},
#   {'po': 3,
#    'n': 'abnormal nervous system physiology:-log(hyper_p)',
#    'v': '1.7807573601984696',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal nervous system physiology:-log(OR_p)',
#    'v': '1.2474093429707664',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal nervous system physiology:log_OR',
#    'v': '1.1141339139722009',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal nervous system physiology:num_genes',
#    'v': '4',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal nervous system physiology:gene_ids',
#    'v': 'EN1 MNX1 NKX6-2 PBX3',
#    'd': 'string'},
#   {'po': 3,
#    'n': 'abnormal nervous system morphology:-log(hyper_p)',
#    'v': '2.466385935595304',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal nervous system morphology:-log(OR_p)',
#    'v': '1.9577194924901609',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal nervous system morphology:log_OR',
#    'v': '1.3407570460591227',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal nervous system morphology:num_genes',
#    'v': '6',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal nervous system morphology:gene_ids',
#    'v': 'EN1 GSX2 IRX1 IRX6 MNX1 NKX6-2',
#    'd': 'string'},
#   {'po': 3,
#    'n': 'abnormal neuron morphology:-log(hyper_p)',
#    'v': '3.2134645525569945',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal neuron morphology:-log(OR_p)',
#    'v': '2.9217672776259365',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal neuron morphology:log_OR',
#    'v': '1.7765339447256583',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal neuron morphology:num_genes',
#    'v': '5',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal neuron morphology:gene_ids',
#    'v': 'EN1 GSX2 IRX6 MNX1 NKX6-2',
#    'd': 'string'},
#   {'po': 3,
#    'n': 'abnormal CNS synaptic transmission:-log(hyper_p)',
#    'v': '0.9288797679488591',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal CNS synaptic transmission:-log(OR_p)',
#    'v': '0.2233383534260932',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal CNS synaptic transmission:log_OR',
#    'v': '0.5462215641193486',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal CNS synaptic transmission:num_genes',
#    'v': '1',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal CNS synaptic transmission:gene_ids',
#    'v': 'EN1',
#    'd': 'string'},
#   {'po': 3,
#    'n': 'abnormal synaptic transmission:-log(hyper_p)',
#    'v': '0.767962219587219',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal synaptic transmission:-log(OR_p)',
#    'v': '0.11517147363945311',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal synaptic transmission:log_OR',
#    'v': '0.3067819354382628',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal synaptic transmission:num_genes',
#    'v': '1',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal synaptic transmission:gene_ids',
#    'v': 'EN1',
#    'd': 'string'},
#   {'po': 3,
#    'n': 'abnormal neuron physiology:-log(hyper_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal neuron physiology:-log(OR_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal neuron physiology:log_OR',
#    'v': '0.0',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal neuron physiology:num_genes',
#    'v': '0',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal neuron physiology:gene_ids',
#    'v': '',
#    'd': 'string'},
#   {'po': 3,
#    'n': 'abnormal nervous system development:-log(hyper_p)',
#    'v': '3.5441477805970587',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal nervous system development:-log(OR_p)',
#    'v': '3.3589296490137204',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal nervous system development:log_OR',
#    'v': '1.9286620046618204',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal nervous system development:num_genes',
#    'v': '5',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal nervous system development:gene_ids',
#    'v': 'EN1 GSX2 IRX1 MNX1 NKX6-2',
#    'd': 'string'},
#   {'po': 3,
#    'n': 'abnormal somatic nervous system morphology:-log(hyper_p)',
#    'v': '4.183996985329966',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal somatic nervous system morphology:-log(OR_p)',
#    'v': '4.2594581331752375',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal somatic nervous system morphology:log_OR',
#    'v': '2.2130530592993933',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal somatic nervous system morphology:num_genes',
#    'v': '5',
#    'd': 'double'},
#   {'po': 3,
#    'n': 'abnormal somatic nervous system morphology:gene_ids',
#    'v': 'EN1 GSX2 IRX6 MNX1 NKX6-2',
#    'd': 'string'}],
#  4: [{'po': 4,
#    'n': 'CD_MemberList',
#    'v': 'CALM3 FSD1 GNAZ SRC',
#    'd': 'string'},
#   {'po': 4, 'n': 'CD_AnnotatedMembers_Size', 'v': '2', 'd': 'string'},
#   {'po': 4,
#    'n': 'CD_AnnotatedMembers_Pvalue',
#    'v': '0.0034578149777732',
#    'd': 'string'},
#   {'po': 4, 'n': 'CD_AnnotatedMembers', 'v': 'SRC CALM3', 'd': 'string'},
#   {'po': 4,
#    'n': 'CD_CommunityName',
#    'v': 'GnRH signaling pathway',
#    'd': 'string'},
#   {'po': 4, 'n': 'CD_AnnotatedMembers_Overlap', 'v': '0.5', 'd': 'string'},
#   {'po': 4, 'n': 'HiDeF_persistence', 'v': '5', 'd': 'string'},
#   {'po': 4, 'n': 'CD_MemberList_LogSize', 'v': '2.0', 'd': 'string'},
#   {'po': 4, 'n': 'CD_Labeled', 'v': 'true', 'd': 'string'},
#   {'po': 4,
#    'n': 'CD_AnnotatedAlgorithm',
#    'v': ['Annotated by Enrichr [Docker: coleslawndex/cdenrichrgenestoterm:0.4.0] {{--maxpval=0.05',
#     ' --genesets=GO_Biological_Process_2018',
#     'GO_Cellular_Component_2018',
#     'GO_Molecular_Function_2018',
#     'KEGG_2019_Human',
#     'Reactome_2016',
#     'WikiPathways_2019_Human',
#     'Human_Phenotype_Ontology',
#     'Jensen_DISEASES}} via CyCommunityDetection Cytoscape App (1.11.0)'],
#    'd': 'list_of_string'},
#   {'po': 4, 'n': 'CD_NonAnnotatedMembers', 'v': 'FSD1 GNAZ', 'd': 'string'},
#   {'po': 4,
#    'n': 'CD_AnnotatedMembers_SourceDB',
#    'v': 'KEGG_2019_Human',
#    'd': 'string'},
#   {'po': 4, 'n': 'CD_MemberList_Size', 'v': '4', 'd': 'string'},
#   {'po': 4, 'n': 'name', 'v': 'C433', 'd': 'string'},
#   {'po': 4,
#    'n': 'abnormal nervous system electrophysiology:-log(hyper_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal nervous system electrophysiology:-log(OR_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal nervous system electrophysiology:log_OR',
#    'v': '0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal nervous system electrophysiology:num_genes',
#    'v': '0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal nervous system electrophysiology:gene_ids',
#    'v': '',
#    'd': 'string'},
#   {'po': 4,
#    'n': 'nervous system phenotype:-log(hyper_p)',
#    'v': '0.7917764586273599',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'nervous system phenotype:-log(OR_p)',
#    'v': '0.12550512890866589',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'nervous system phenotype:log_OR',
#    'v': '0.36947001933877743',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'nervous system phenotype:num_genes',
#    'v': '1',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'nervous system phenotype:gene_ids',
#    'v': 'GNAZ',
#    'd': 'string'},
#   {'po': 4,
#    'n': 'abnormal nervous system physiology:-log(hyper_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal nervous system physiology:-log(OR_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal nervous system physiology:log_OR',
#    'v': '0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal nervous system physiology:num_genes',
#    'v': '0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal nervous system physiology:gene_ids',
#    'v': '',
#    'd': 'string'},
#   {'po': 4,
#    'n': 'abnormal nervous system morphology:-log(hyper_p)',
#    'v': '0.9671965915076828',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal nervous system morphology:-log(OR_p)',
#    'v': '0.2397303521006409',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal nervous system morphology:log_OR',
#    'v': '0.646195924990093',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal nervous system morphology:num_genes',
#    'v': '1',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal nervous system morphology:gene_ids',
#    'v': 'GNAZ',
#    'd': 'string'},
#   {'po': 4,
#    'n': 'abnormal neuron morphology:-log(hyper_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal neuron morphology:-log(OR_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal neuron morphology:log_OR',
#    'v': '0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal neuron morphology:num_genes',
#    'v': '0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal neuron morphology:gene_ids',
#    'v': '',
#    'd': 'string'},
#   {'po': 4,
#    'n': 'abnormal CNS synaptic transmission:-log(hyper_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal CNS synaptic transmission:-log(OR_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal CNS synaptic transmission:log_OR',
#    'v': '0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal CNS synaptic transmission:num_genes',
#    'v': '0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal CNS synaptic transmission:gene_ids',
#    'v': '',
#    'd': 'string'},
#   {'po': 4,
#    'n': 'abnormal synaptic transmission:-log(hyper_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal synaptic transmission:-log(OR_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal synaptic transmission:log_OR',
#    'v': '0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal synaptic transmission:num_genes',
#    'v': '0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal synaptic transmission:gene_ids',
#    'v': '',
#    'd': 'string'},
#   {'po': 4,
#    'n': 'abnormal neuron physiology:-log(hyper_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal neuron physiology:-log(OR_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal neuron physiology:log_OR',
#    'v': '0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal neuron physiology:num_genes',
#    'v': '0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal neuron physiology:gene_ids',
#    'v': '',
#    'd': 'string'},
#   {'po': 4,
#    'n': 'abnormal nervous system development:-log(hyper_p)',
#    'v': '1.5977543504522835',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal nervous system development:-log(OR_p)',
#    'v': '0.725706616567776',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal nervous system development:log_OR',
#    'v': '1.5204613107337117',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal nervous system development:num_genes',
#    'v': '1',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal nervous system development:gene_ids',
#    'v': 'GNAZ',
#    'd': 'string'},
#   {'po': 4,
#    'n': 'abnormal somatic nervous system morphology:-log(hyper_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal somatic nervous system morphology:-log(OR_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal somatic nervous system morphology:log_OR',
#    'v': '0.0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal somatic nervous system morphology:num_genes',
#    'v': '0',
#    'd': 'double'},
#   {'po': 4,
#    'n': 'abnormal somatic nervous system morphology:gene_ids',
#    'v': '',
#    'd': 'string'}],
#  5: [{'po': 5,
#    'n': 'CD_MemberList',
#    'v': 'ABCC8 ACTN2 ADARB2 BRINP3 C14orf132 CADM2 CALB1 CALB2 CALM1 CALM3 CALML3 CCK CDK5R2 CHRNA7 CNTN1 CRHBP DCP1B DNM1 DPYSL2 ENC1 ENHO EPHA4 FABP7 FAM171B FGF14 FGFR2 FSD1 GABRA2 GABRB2 GABRB3 GABRG1 GABRG2 GAD1 GFAP GNAZ GRIP2 GRM7 INA IRF2BPL JAKMIP1 KANK4 KCNA1 KCNA2 KCNA3 KCNA4 KCNA7 KCNB1 KCNC1 KCNC2 KCND2 KCNF1 KCNH5 KCNH7 KCNJ10 KCNK10 KCNK12 KCNK13 KCNK5 KCNK9 KCNMA1 KCNN2 KCNQ2 KCNQ3 KCNQ4 KCNQ5 KCNT1 KCNT2 KIF1A KIF5C LGI1 LRRC26 LRRTM3 LRRTM4 LRTM2 LSAMP MAPT MKRN3 MOG MPZ NCAM1 NEFM NEGR1 NEUROD1 NSF NSG2 NTM NTRK2 OMG OPCML PCSK1 PIN1P1 PLP1 PPP1R3F PPP2R3A PRELP PRR36 PSD2 SCN3A SCN3B SCN8A SCUBE3 SLC17A6 SLC17A7 SLC1A2 SLC6A1 SLITRK1 SLITRK5 SPTBN1 SRC STMN3 STXBP5L SV2A SV2B SYBU SYN1 SYP TANC2 TBR1 TIGD6 TMEM63A TNIK UNC13B UNC13C UNC13D UNC5C VSNL1 ZNF501',
#    'd': 'string'},
#   {'po': 5, 'n': 'CD_AnnotatedMembers_Size', 'v': '38', 'd': 'string'},
#   {'po': 5,
#    'n': 'CD_AnnotatedMembers_Pvalue',
#    'v': '1.898964914130819E-36',
#    'd': 'string'},
#   {'po': 5,
#    'n': 'CD_AnnotatedMembers',
#    'v': 'GABRB3 GABRB2 KCNC1 KCNK9 KCNC2 CHRNA7 KCNA1 KCNA2 SLC1A2 KCNA3 KCNA4 SLC6A1 KCNA7 KCNN2 SLC17A7 UNC13B NSF GABRA2 KCNF1 KCNJ10 KCNH5 KCND2 KCNK10 ACTN2 ABCC8 KCNB1 KCNH7 GAD1 KCNK13 GRIP2 SYN1 GABRG2 KCNMA1 KCNQ2 KCNQ3 KCNQ4 KCNQ5 CALM1',
#    'd': 'string'},
#   {'po': 5,
#    'n': 'CD_CommunityName',
#    'v': 'Neuronal System Homo sapiens R-HSA-112316',
#    'd': 'string'},
#   {'po': 5, 'n': 'CD_AnnotatedMembers_Overlap', 'v': '0.299', 'd': 'string'},
#   {'po': 5, 'n': 'HiDeF_persistence', 'v': '21', 'd': 'string'},
#   {'po': 5, 'n': 'CD_MemberList_LogSize', 'v': '6.989', 'd': 'string'},
#   {'po': 5, 'n': 'CD_Labeled', 'v': 'true', 'd': 'string'},
#   {'po': 5,
#    'n': 'CD_AnnotatedAlgorithm',
#    'v': ['Annotated by Enrichr [Docker: coleslawndex/cdenrichrgenestoterm:0.4.0] {{--maxpval=0.05',
#     ' --genesets=GO_Biological_Process_2018',
#     'GO_Cellular_Component_2018',
#     'GO_Molecular_Function_2018',
#     'KEGG_2019_Human',
#     'Reactome_2016',
#     'WikiPathways_2019_Human',
#     'Human_Phenotype_Ontology',
#     'Jensen_DISEASES}} via CyCommunityDetection Cytoscape App (1.11.0)'],
#    'd': 'list_of_string'},
#   {'po': 5,
#    'n': 'CD_NonAnnotatedMembers',
#    'v': 'ADARB2 BRINP3 C14orf132 CADM2 CALB1 CALB2 CALM3 CALML3 CCK CDK5R2 CNTN1 CRHBP DCP1B DNM1 DPYSL2 ENC1 ENHO EPHA4 FABP7 FAM171B FGF14 FGFR2 FSD1 GABRG1 GFAP GNAZ GRM7 INA IRF2BPL JAKMIP1 KANK4 KCNK12 KCNK5 KCNT1 KCNT2 KIF1A KIF5C LGI1 LRRC26 LRRTM3 LRRTM4 LRTM2 LSAMP MAPT MKRN3 MOG MPZ NCAM1 NEFM NEGR1 NEUROD1 NSG2 NTM NTRK2 OMG OPCML PCSK1 PIN1P1 PLP1 PPP1R3F PPP2R3A PRELP PRR36 PSD2 SCN3A SCN3B SCN8A SCUBE3 SLC17A6 SLITRK1 SLITRK5 SPTBN1 SRC STMN3 STXBP5L SV2A SV2B SYBU SYP TANC2 TBR1 TIGD6 TMEM63A TNIK UNC13C UNC13D UNC5C VSNL1 ZNF501',
#    'd': 'string'},
#   {'po': 5,
#    'n': 'CD_AnnotatedMembers_SourceDB',
#    'v': 'Reactome_2016',
#    'd': 'string'},
#   {'po': 5, 'n': 'CD_MemberList_Size', 'v': '127', 'd': 'string'},
#   {'po': 5, 'n': 'name', 'v': 'C365', 'd': 'string'},
#   {'po': 5,
#    'n': 'abnormal nervous system electrophysiology:-log(hyper_p)',
#    'v': '23.958360598345717',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal nervous system electrophysiology:-log(OR_p)',
#    'v': '37.763951817396176',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal nervous system electrophysiology:log_OR',
#    'v': '2.8804911477187063',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal nervous system electrophysiology:num_genes',
#    'v': '28',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal nervous system electrophysiology:gene_ids',
#    'v': 'CALB1 CALB2 DNM1 FGF14 GABRB3 GABRG2 GAD1 GRM7 JAKMIP1 KCNA1 KCNA2 KCNC2 KCNJ10 KCNK9 KCNMA1 KCNN2 KCNQ2 KCNQ3 KCNQ5 KCNT1 LGI1 LRRTM3 MPZ NEFM NEUROD1 PLP1 SCN8A SLC17A7',
#    'd': 'string'},
#   {'po': 5,
#    'n': 'nervous system phenotype:-log(hyper_p)',
#    'v': '23.19775121389292',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'nervous system phenotype:-log(OR_p)',
#    'v': '23.064580529508522',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'nervous system phenotype:log_OR',
#    'v': '1.8195193298884833',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'nervous system phenotype:num_genes',
#    'v': '74',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'nervous system phenotype:gene_ids',
#    'v': 'CALB1 CALB2 CCK CDK5R2 CHRNA7 CNTN1 DNM1 DPYSL2 ENHO EPHA4 FABP7 FGF14 FGFR2 GABRA2 GABRB2 GABRB3 GABRG2 GAD1 GFAP GNAZ GRM7 INA JAKMIP1 KCNA1 KCNA2 KCNA4 KCNB1 KCNC1 KCNC2 KCND2 KCNJ10 KCNK13 KCNK5 KCNK9 KCNMA1 KCNN2 KCNQ2 KCNQ3 KCNQ4 KCNQ5 KCNT1 KIF1A KIF5C LGI1 LRRTM3 LRRTM4 MAPT MOG MPZ NCAM1 NEFM NEUROD1 NTRK2 PLP1 PSD2 SCN8A SLC17A6 SLC17A7 SLC1A2 SLC6A1 SLITRK1 SLITRK5 SPTBN1 STXBP5L SV2A SV2B SYN1 SYP TBR1 TNIK UNC13B UNC13C UNC13D UNC5C',
#    'd': 'string'},
#   {'po': 5,
#    'n': 'abnormal nervous system physiology:-log(hyper_p)',
#    'v': '29.399936311424007',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal nervous system physiology:-log(OR_p)',
#    'v': '33.03014597770173',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal nervous system physiology:log_OR',
#    'v': '2.1687652280546263',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal nervous system physiology:num_genes',
#    'v': '64',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal nervous system physiology:gene_ids',
#    'v': 'CALB1 CALB2 CCK CHRNA7 DNM1 EPHA4 FABP7 FGF14 FGFR2 GABRA2 GABRB2 GABRB3 GABRG2 GAD1 GFAP GRM7 INA JAKMIP1 KCNA1 KCNA2 KCNA4 KCNC1 KCNC2 KCND2 KCNJ10 KCNK13 KCNK5 KCNK9 KCNMA1 KCNN2 KCNQ2 KCNQ3 KCNQ4 KCNQ5 KCNT1 KIF1A LGI1 LRRTM3 LRRTM4 MAPT MOG MPZ NEFM NEUROD1 NTRK2 PLP1 SCN8A SLC17A6 SLC17A7 SLC1A2 SLC6A1 SLITRK1 SLITRK5 STXBP5L SV2A SV2B SYN1 SYP TBR1 TNIK UNC13B UNC13C UNC13D UNC5C',
#    'd': 'string'},
#   {'po': 5,
#    'n': 'abnormal nervous system morphology:-log(hyper_p)',
#    'v': '13.974375200727879',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal nervous system morphology:-log(OR_p)',
#    'v': '15.15333508996633',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal nervous system morphology:log_OR',
#    'v': '1.458076959973499',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal nervous system morphology:num_genes',
#    'v': '54',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal nervous system morphology:gene_ids',
#    'v': 'CDK5R2 CHRNA7 CNTN1 DNM1 DPYSL2 ENHO EPHA4 FABP7 FGF14 FGFR2 GABRB2 GABRB3 GABRG2 GAD1 GFAP GNAZ GRM7 JAKMIP1 KCNA1 KCNB1 KCND2 KCNJ10 KCNK13 KCNK5 KCNMA1 KCNN2 KCNQ3 KCNQ4 KIF1A KIF5C LGI1 LRRTM3 LRRTM4 MAPT MOG MPZ NCAM1 NEFM NEUROD1 NTRK2 PLP1 PSD2 SCN8A SLC17A6 SLC17A7 SLC1A2 SLITRK5 SPTBN1 STXBP5L SYN1 TBR1 TNIK UNC13B UNC5C',
#    'd': 'string'},
#   {'po': 5,
#    'n': 'abnormal neuron morphology:-log(hyper_p)',
#    'v': '14.917426581761257',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal neuron morphology:-log(OR_p)',
#    'v': '18.143977853600344',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal neuron morphology:log_OR',
#    'v': '1.7123488883254514',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal neuron morphology:num_genes',
#    'v': '40',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal neuron morphology:gene_ids',
#    'v': 'CDK5R2 CHRNA7 CNTN1 DNM1 DPYSL2 ENHO EPHA4 FGF14 FGFR2 GABRB2 GABRB3 GABRG2 GRM7 KCNB1 KCND2 KCNJ10 KCNMA1 KCNQ4 KIF1A KIF5C LRRTM3 MAPT MOG MPZ NCAM1 NEFM NEUROD1 NTRK2 PLP1 PSD2 SCN8A SLC17A6 SLC17A7 SLC1A2 SLITRK5 SYN1 TBR1 TNIK UNC13B UNC5C',
#    'd': 'string'},
#   {'po': 5,
#    'n': 'abnormal CNS synaptic transmission:-log(hyper_p)',
#    'v': '23.58256386824705',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal CNS synaptic transmission:-log(OR_p)',
#    'v': '32.7309996640427',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal CNS synaptic transmission:log_OR',
#    'v': '2.3808669661240813',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal CNS synaptic transmission:num_genes',
#    'v': '38',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal CNS synaptic transmission:gene_ids',
#    'v': 'CALB2 CCK CHRNA7 DNM1 EPHA4 FABP7 FGF14 GABRA2 GABRB2 GABRB3 GABRG2 GAD1 GFAP GRM7 KCNA1 KCNA2 KCNC2 KCNJ10 KCNMA1 KCNN2 KCNQ2 LGI1 LRRTM3 LRRTM4 MAPT MPZ NTRK2 SCN8A SLC17A6 SLC17A7 SLC6A1 STXBP5L SV2A SYN1 SYP TBR1 TNIK UNC13C',
#    'd': 'string'},
#   {'po': 5,
#    'n': 'abnormal synaptic transmission:-log(hyper_p)',
#    'v': '24.95385443462696',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal synaptic transmission:-log(OR_p)',
#    'v': '33.301664684536505',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal synaptic transmission:log_OR',
#    'v': '2.3180564467173848',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal synaptic transmission:num_genes',
#    'v': '43',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal synaptic transmission:gene_ids',
#    'v': 'CALB2 CCK CHRNA7 DNM1 EPHA4 FABP7 FGF14 GABRA2 GABRB2 GABRB3 GABRG2 GAD1 GFAP GRM7 KCNA1 KCNA2 KCNC2 KCND2 KCNJ10 KCNK9 KCNMA1 KCNN2 KCNQ2 KCNT1 LGI1 LRRTM3 LRRTM4 MAPT MPZ NTRK2 SCN8A SLC17A6 SLC17A7 SLC6A1 SLITRK1 SLITRK5 STXBP5L SV2A SYN1 SYP TBR1 TNIK UNC13C',
#    'd': 'string'},
#   {'po': 5,
#    'n': 'abnormal neuron physiology:-log(hyper_p)',
#    'v': '12.674733374800406',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal neuron physiology:-log(OR_p)',
#    'v': '17.301228687367438',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal neuron physiology:log_OR',
#    'v': '1.9954118362348505',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal neuron physiology:num_genes',
#    'v': '24',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal neuron physiology:gene_ids',
#    'v': 'CHRNA7 DNM1 FGFR2 GABRG2 GAD1 GFAP GRM7 INA KCNMA1 KCNQ2 KCNQ3 KCNQ4 KCNT1 KIF1A MAPT MOG NEFM NEUROD1 NTRK2 PLP1 SCN8A SYN1 TBR1 UNC5C',
#    'd': 'string'},
#   {'po': 5,
#    'n': 'abnormal nervous system development:-log(hyper_p)',
#    'v': '5.373997277884246',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal nervous system development:-log(OR_p)',
#    'v': '5.8640503987683115',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal nervous system development:log_OR',
#    'v': '1.1217656340771267',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal nervous system development:num_genes',
#    'v': '23',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal nervous system development:gene_ids',
#    'v': 'CDK5R2 CHRNA7 CNTN1 EPHA4 FGFR2 GFAP GNAZ KCNA1 LGI1 LRRTM4 MAPT MPZ NCAM1 NEFM NEUROD1 NTRK2 PLP1 SCN8A SPTBN1 SYN1 TBR1 TNIK UNC5C',
#    'd': 'string'},
#   {'po': 5,
#    'n': 'abnormal somatic nervous system morphology:-log(hyper_p)',
#    'v': '6.824599264626495',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal somatic nervous system morphology:-log(OR_p)',
#    'v': '7.983147230080478',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal somatic nervous system morphology:log_OR',
#    'v': '1.3555296924376554',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal somatic nervous system morphology:num_genes',
#    'v': '22',
#    'd': 'double'},
#   {'po': 5,
#    'n': 'abnormal somatic nervous system morphology:gene_ids',
# ...
#    'd': 'double'},
#   {'po': 70,
#    'n': 'abnormal neuron physiology:num_genes',
#    'v': '1',
#    'd': 'double'},
#   {'po': 70,
#    'n': 'abnormal neuron physiology:gene_ids',
#    'v': 'ZBTB18',
#    'd': 'string'},
#   {'po': 70,
#    'n': 'abnormal nervous system development:-log(hyper_p)',
#    'v': '1.868522860057068',
#    'd': 'double'},
#   {'po': 70,
#    'n': 'abnormal nervous system development:-log(OR_p)',
#    'v': '1.2031633802232005',
#    'd': 'double'},
#   {'po': 70,
#    'n': 'abnormal nervous system development:log_OR',
#    'v': '1.52107301787363',
#    'd': 'double'},
#   {'po': 70,
#    'n': 'abnormal nervous system development:num_genes',
#    'v': '2',
#    'd': 'double'},
#   {'po': 70,
#    'n': 'abnormal nervous system development:gene_ids',
#    'v': 'ZBTB18 ZEB1',
#    'd': 'string'},
#   {'po': 70,
#    'n': 'abnormal somatic nervous system morphology:-log(hyper_p)',
#    'v': '1.2108850384568572',
#    'd': 'double'},
#   {'po': 70,
#    'n': 'abnormal somatic nervous system morphology:-log(OR_p)',
#    'v': '0.4303591671192936',
#    'd': 'double'},
#   {'po': 70,
#    'n': 'abnormal somatic nervous system morphology:log_OR',
#    'v': '0.9563641608666895',
#    'd': 'double'},
#   {'po': 70,
#    'n': 'abnormal somatic nervous system morphology:num_genes',
#    'v': '1',
#    'd': 'double'},
#   {'po': 70,
#    'n': 'abnormal somatic nervous system morphology:gene_ids',
#    'v': 'ZEB1',
#    'd': 'string'}],
#  71: [{'po': 71,
#    'n': 'CD_MemberList',
#    'v': 'BRINP3 C14orf132 CHRNA7 GABRB3 INA JAKMIP1 MAPT NSG2 PIN1P1 PRR36 SV2A',
#    'd': 'string'},
#   {'po': 71, 'n': 'CD_AnnotatedMembers_Size', 'v': '2', 'd': 'string'},
#   {'po': 71,
#    'n': 'CD_AnnotatedMembers_Pvalue',
#    'v': '0.0025448553292433',
#    'd': 'string'},
#   {'po': 71, 'n': 'CD_AnnotatedMembers', 'v': 'GABRB3 CHRNA7', 'd': 'string'},
#   {'po': 71,
#    'n': 'CD_CommunityName',
#    'v': 'Nicotine addiction',
#    'd': 'string'},
#   {'po': 71, 'n': 'CD_AnnotatedMembers_Overlap', 'v': '0.182', 'd': 'string'},
#   {'po': 71, 'n': 'HiDeF_persistence', 'v': '5', 'd': 'string'},
#   {'po': 71, 'n': 'CD_MemberList_LogSize', 'v': '3.459', 'd': 'string'},
#   {'po': 71, 'n': 'CD_Labeled', 'v': 'true', 'd': 'string'},
#   {'po': 71,
#    'n': 'CD_AnnotatedAlgorithm',
#    'v': ['Annotated by Enrichr [Docker: coleslawndex/cdenrichrgenestoterm:0.4.0] {{--maxpval=0.05',
#     ' --genesets=GO_Biological_Process_2018',
#     'GO_Cellular_Component_2018',
#     'GO_Molecular_Function_2018',
#     'KEGG_2019_Human',
#     'Reactome_2016',
#     'WikiPathways_2019_Human',
#     'Human_Phenotype_Ontology',
#     'Jensen_DISEASES}} via CyCommunityDetection Cytoscape App (1.11.0)'],
#    'd': 'list_of_string'},
#   {'po': 71,
#    'n': 'CD_NonAnnotatedMembers',
#    'v': 'BRINP3 C14orf132 INA JAKMIP1 MAPT NSG2 PIN1P1 PRR36 SV2A',
#    'd': 'string'},
#   {'po': 71,
#    'n': 'CD_AnnotatedMembers_SourceDB',
#    'v': 'KEGG_2019_Human',
#    'd': 'string'},
#   {'po': 71, 'n': 'CD_MemberList_Size', 'v': '11', 'd': 'string'},
#   {'po': 71, 'n': 'name', 'v': 'C375', 'd': 'string'},
#   {'po': 71,
#    'n': 'abnormal nervous system electrophysiology:-log(hyper_p)',
#    'v': '3.1389885859811586',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal nervous system electrophysiology:-log(OR_p)',
#    'v': '2.9604770418397273',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal nervous system electrophysiology:log_OR',
#    'v': '2.558910626650535',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal nervous system electrophysiology:num_genes',
#    'v': '2',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal nervous system electrophysiology:gene_ids',
#    'v': 'GABRB3 JAKMIP1',
#    'd': 'string'},
#   {'po': 71,
#    'n': 'nervous system phenotype:-log(hyper_p)',
#    'v': '2.885381276856667',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'nervous system phenotype:-log(OR_p)',
#    'v': '2.19359740139192',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'nervous system phenotype:log_OR',
#    'v': '1.6516933305046013',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'nervous system phenotype:num_genes',
#    'v': '6',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'nervous system phenotype:gene_ids',
#    'v': 'CHRNA7 GABRB3 INA JAKMIP1 MAPT SV2A',
#    'd': 'string'},
#   {'po': 71,
#    'n': 'abnormal nervous system physiology:-log(hyper_p)',
#    'v': '4.4563839711712685',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal nervous system physiology:-log(OR_p)',
#    'v': '3.858784148501848',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal nervous system physiology:log_OR',
#    'v': '2.309411465616302',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal nervous system physiology:num_genes',
#    'v': '6',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal nervous system physiology:gene_ids',
#    'v': 'CHRNA7 GABRB3 INA JAKMIP1 MAPT SV2A',
#    'd': 'string'},
#   {'po': 71,
#    'n': 'abnormal nervous system morphology:-log(hyper_p)',
#    'v': '1.8151867490125837',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal nervous system morphology:-log(OR_p)',
#    'v': '1.232134463815233',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal nervous system morphology:log_OR',
#    'v': '1.186015445107957',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal nervous system morphology:num_genes',
#    'v': '4',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal nervous system morphology:gene_ids',
#    'v': 'CHRNA7 GABRB3 JAKMIP1 MAPT',
#    'd': 'string'},
#   {'po': 71,
#    'n': 'abnormal neuron morphology:-log(hyper_p)',
#    'v': '2.104194946795898',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal neuron morphology:-log(OR_p)',
#    'v': '1.5509424961933094',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal neuron morphology:log_OR',
#    'v': '1.4876048211489303',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal neuron morphology:num_genes',
#    'v': '3',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal neuron morphology:gene_ids',
#    'v': 'CHRNA7 GABRB3 MAPT',
#    'd': 'string'},
#   {'po': 71,
#    'n': 'abnormal CNS synaptic transmission:-log(hyper_p)',
#    'v': '4.431521251372429',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal CNS synaptic transmission:-log(OR_p)',
#    'v': '4.5519672627775964',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal CNS synaptic transmission:log_OR',
#    'v': '2.6300748208132267',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal CNS synaptic transmission:num_genes',
#    'v': '4',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal CNS synaptic transmission:gene_ids',
#    'v': 'CHRNA7 GABRB3 MAPT SV2A',
#    'd': 'string'},
#   {'po': 71,
#    'n': 'abnormal synaptic transmission:-log(hyper_p)',
#    'v': '3.957082955232113',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal synaptic transmission:-log(OR_p)',
#    'v': '3.85249105061854',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal synaptic transmission:log_OR',
#    'v': '2.3898152087773648',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal synaptic transmission:num_genes',
#    'v': '4',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal synaptic transmission:gene_ids',
#    'v': 'CHRNA7 GABRB3 MAPT SV2A',
#    'd': 'string'},
#   {'po': 71,
#    'n': 'abnormal neuron physiology:-log(hyper_p)',
#    'v': '3.554903407206651',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal neuron physiology:-log(OR_p)',
#    'v': '3.494158402456437',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal neuron physiology:log_OR',
#    'v': '2.4405551495704083',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal neuron physiology:num_genes',
#    'v': '3',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal neuron physiology:gene_ids',
#    'v': 'CHRNA7 INA MAPT',
#    'd': 'string'},
#   {'po': 71,
#    'n': 'abnormal nervous system development:-log(hyper_p)',
#    'v': '1.4657109384431115',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal nervous system development:-log(OR_p)',
#    'v': '0.8127625546604128',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal nervous system development:log_OR',
#    'v': '1.1154368087298865',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal nervous system development:num_genes',
#    'v': '2',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal nervous system development:gene_ids',
#    'v': 'CHRNA7 MAPT',
#    'd': 'string'},
#   {'po': 71,
#    'n': 'abnormal somatic nervous system morphology:-log(hyper_p)',
#    'v': '2.7457222872027627',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal somatic nervous system morphology:-log(OR_p)',
#    'v': '2.342644568014161',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal somatic nervous system morphology:log_OR',
#    'v': '1.923433970011196',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal somatic nervous system morphology:num_genes',
#    'v': '3',
#    'd': 'double'},
#   {'po': 71,
#    'n': 'abnormal somatic nervous system morphology:gene_ids',
#    'v': 'CHRNA7 GABRB3 MAPT',
#    'd': 'string'}],
#  72: [{'po': 72,
#    'n': 'CD_MemberList',
#    'v': 'KCNA3 KCNA4 KCNA7 KCNC2 KCNF1 KCNH5 KCNK12 KCNK13 KCNK5 KCNK9 KCNN2 KCNQ2 KCNQ3 KCNQ4 KCNQ5 KCNT1',
#    'd': 'string'},
#   {'po': 72, 'n': 'CD_AnnotatedMembers_Size', 'v': '16', 'd': 'string'},
#   {'po': 72,
#    'n': 'CD_AnnotatedMembers_Pvalue',
#    'v': '7.753285348939722E-37',
#    'd': 'string'},
#   {'po': 72,
#    'n': 'CD_AnnotatedMembers',
#    'v': 'KCNK5 KCNF1 KCNH5 KCNK9 KCNC2 KCNK12 KCNK13 KCNA3 KCNA4 KCNA7 KCNT1 KCNQ2 KCNQ3 KCNQ4 KCNN2 KCNQ5',
#    'd': 'string'},
#   {'po': 72,
#    'n': 'CD_CommunityName',
#    'v': 'potassium channel activity (GO:0005267)',
#    'd': 'string'},
#   {'po': 72, 'n': 'CD_AnnotatedMembers_Overlap', 'v': '1.0', 'd': 'string'},
#   {'po': 72, 'n': 'HiDeF_persistence', 'v': '5', 'd': 'string'},
#   {'po': 72, 'n': 'CD_MemberList_LogSize', 'v': '4.0', 'd': 'string'},
#   {'po': 72, 'n': 'CD_Labeled', 'v': 'true', 'd': 'string'},
#   {'po': 72,
#    'n': 'CD_AnnotatedAlgorithm',
#    'v': ['Annotated by Enrichr [Docker: coleslawndex/cdenrichrgenestoterm:0.4.0] {{--maxpval=0.05',
#     ' --genesets=GO_Biological_Process_2018',
#     'GO_Cellular_Component_2018',
#     'GO_Molecular_Function_2018',
#     'KEGG_2019_Human',
#     'Reactome_2016',
#     'WikiPathways_2019_Human',
#     'Human_Phenotype_Ontology',
#     'Jensen_DISEASES}} via CyCommunityDetection Cytoscape App (1.11.0)'],
#    'd': 'list_of_string'},
#   {'po': 72,
#    'n': 'CD_AnnotatedMembers_SourceDB',
#    'v': 'GO_Molecular_Function_2018',
#    'd': 'string'},
#   {'po': 72, 'n': 'CD_MemberList_Size', 'v': '16', 'd': 'string'},
#   {'po': 72, 'n': 'name', 'v': 'C371', 'd': 'string'},
#   {'po': 72,
#    'n': 'abnormal nervous system electrophysiology:-log(hyper_p)',
#    'v': '10.135409519976058',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal nervous system electrophysiology:-log(OR_p)',
#    'v': '13.350863037859824',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal nervous system electrophysiology:log_OR',
#    'v': '3.827521787385927',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal nervous system electrophysiology:num_genes',
#    'v': '7',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal nervous system electrophysiology:gene_ids',
#    'v': 'KCNC2 KCNK9 KCNN2 KCNQ2 KCNQ3 KCNQ5 KCNT1',
#    'd': 'string'},
#   {'po': 72,
#    'n': 'nervous system phenotype:-log(hyper_p)',
#    'v': '5.805540110845767',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'nervous system phenotype:-log(OR_p)',
#    'v': '4.547285182681301',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'nervous system phenotype:log_OR',
#    'v': '2.2592514071065946',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'nervous system phenotype:num_genes',
#    'v': '11',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'nervous system phenotype:gene_ids',
#    'v': 'KCNA4 KCNC2 KCNK13 KCNK5 KCNK9 KCNN2 KCNQ2 KCNQ3 KCNQ4 KCNQ5 KCNT1',
#    'd': 'string'},
#   {'po': 72,
#    'n': 'abnormal nervous system physiology:-log(hyper_p)',
#    'v': '8.591399753511624',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal nervous system physiology:-log(OR_p)',
#    'v': '7.188377074636523',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal nervous system physiology:log_OR',
#    'v': '2.918046645643937',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal nervous system physiology:num_genes',
#    'v': '11',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal nervous system physiology:gene_ids',
#    'v': 'KCNA4 KCNC2 KCNK13 KCNK5 KCNK9 KCNN2 KCNQ2 KCNQ3 KCNQ4 KCNQ5 KCNT1',
#    'd': 'string'},
#   {'po': 72,
#    'n': 'abnormal nervous system morphology:-log(hyper_p)',
#    'v': '1.6460936566302626',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal nervous system morphology:-log(OR_p)',
#    'v': '1.118416970439837',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal nervous system morphology:log_OR',
#    'v': '0.957281905809583',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal nervous system morphology:num_genes',
#    'v': '5',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal nervous system morphology:gene_ids',
#    'v': 'KCNK13 KCNK5 KCNN2 KCNQ3 KCNQ4',
#    'd': 'string'},
#   {'po': 72,
#    'n': 'abnormal neuron morphology:-log(hyper_p)',
#    'v': '0.44432380601584065',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal neuron morphology:-log(OR_p)',
#    'v': '0.08869935549348289',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal neuron morphology:log_OR',
#    'v': '-0.24138044376233836',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal neuron morphology:num_genes',
#    'v': '1',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal neuron morphology:gene_ids',
#    'v': 'KCNQ4',
#    'd': 'string'},
#   {'po': 72,
#    'n': 'abnormal CNS synaptic transmission:-log(hyper_p)',
#    'v': '2.512406007476838',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal CNS synaptic transmission:-log(OR_p)',
#    'v': '2.1374077698218628',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal CNS synaptic transmission:log_OR',
#    'v': '1.7216781672793564',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal CNS synaptic transmission:num_genes',
#    'v': '3',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal CNS synaptic transmission:gene_ids',
#    'v': 'KCNC2 KCNN2 KCNQ2',
#    'd': 'string'},
#   {'po': 72,
#    'n': 'abnormal synaptic transmission:-log(hyper_p)',
#    'v': '4.100089455372861',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal synaptic transmission:-log(OR_p)',
#    'v': '4.199017503015927',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal synaptic transmission:log_OR',
#    'v': '2.1618187572257037',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal synaptic transmission:num_genes',
#    'v': '5',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal synaptic transmission:gene_ids',
#    'v': 'KCNC2 KCNK9 KCNN2 KCNQ2 KCNT1',
#    'd': 'string'},
#   {'po': 72,
#    'n': 'abnormal neuron physiology:-log(hyper_p)',
#    'v': '3.983032790110527',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal neuron physiology:-log(OR_p)',
#    'v': '4.22631296154103',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal neuron physiology:log_OR',
#    'v': '2.324234564690899',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal neuron physiology:num_genes',
#    'v': '4',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal neuron physiology:gene_ids',
#    'v': 'KCNQ2 KCNQ3 KCNQ4 KCNT1',
#    'd': 'string'},
#   {'po': 72,
#    'n': 'abnormal nervous system development:-log(hyper_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal nervous system development:-log(OR_p)',
#    'v': '-0.0',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal nervous system development:log_OR',
#    'v': '0.0',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal nervous system development:num_genes',
#    'v': '0',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal nervous system development:gene_ids',
#    'v': '',
#    'd': 'string'},
#   {'po': 72,
#    'n': 'abnormal somatic nervous system morphology:-log(hyper_p)',
#    'v': '0.6959495366003771',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal somatic nervous system morphology:-log(OR_p)',
#    'v': '0.06994438454117441',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal somatic nervous system morphology:log_OR',
#    'v': '0.19377540164977525',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal somatic nervous system morphology:num_genes',
#    'v': '1',
#    'd': 'double'},
#   {'po': 72,
#    'n': 'abnormal somatic nervous system morphology:gene_ids',
#    'v': 'KCNQ4',
#    'd': 'string'}]}

# %%
# update the network on ndex
ndex_password=getpass.getpass('NDEx password: ') # enter password again (not sure if necessary)
G_ASD_cx.update_to(ASD_uuid,ndex_server,ndex_user,ndex_password)
# Out:
# NDEx password: ········
# Generating CX
# ''

# %%
G_ASD_cx.update_to?

# %%
# Out:
# 0.0
